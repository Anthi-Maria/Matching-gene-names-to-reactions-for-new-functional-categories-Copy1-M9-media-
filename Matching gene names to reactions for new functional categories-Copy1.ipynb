# %%
import numpy as np
import pandas as pd
import cobra.test
import os
from os.path import join

from time import time

a= cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7fc036d02850>,
#             <Reaction 12PPDStex at 0x7fc036d02d30>,
#             <Reaction 23CAMPtex at 0x7fc036c8f910>,
#             <Reaction 23CCMPtex at 0x7fc036c8feb0>,
#             <Reaction 23CGMPtex at 0x7fc036c8fca0>,
#             <Reaction 23CUMPtex at 0x7fc036c8ff10>,
#             <Reaction 23DAPPAtex at 0x7fc036c8f790>,
#             <Reaction 26DAHtex at 0x7fc036ca9e50>,
#             <Reaction 34dhpactex at 0x7fc036c12ac0>,
#             <Reaction 3AMPtex at 0x7fc036c12cd0>,
#             <Reaction 3CMPtex at 0x7fc036c86430>,
#             <Reaction 3GMPtex at 0x7fc036c1af10>,
#             <Reaction 3HPPtex at 0x7fc036c4a8e0>,
#             <Reaction 3PEPTtex at 0x7fc036bbbeb0>,
#             <Reaction 3UMPtex at 0x7fc036b4ff40>,
#             <Reaction 3hoxpactex at 0x7fc01bb34c10>,
#             <Reaction 4HOXPACDtex at 0x7fc036b4feb0>,
#             <Reaction 4PEPTtex at 0x7fc036b62be0>,
#             <Reaction 4hoxpactex at 0x7fc01bb34670>,
#             <Reaction 5DGLCNtex at 0x7fc036b4f610>,
#             <Reaction 5MTRtex at 0x7fc036b77e50>,
#             <Reaction 6APAt1 at 0x7fc01bb48b80>,
#             <Reaction ABUTtex at 0x7fc036bdd2b0>,
#             <Reaction ACACtex at 0x7fc036c09ee0>,
#             <Reaction ACALDtex at 0x7fc036b94190>,
#             <Reaction ACGAL1Ptex at 0x7fc036bbbdf0>,
#             <Reaction ACGALtex at 0x7fc036bbbbb0>,
#             <Reaction ACGAM1Ptex at 0x7fc036ba9d60>,
#             <Reaction ACGAtex at 0x7fc036bbbe50>,
#             <Reaction ACMANAtex at 0x7fc036b62fd0>,
#             <Reaction ACMUMtex at 0x7fc036b77ca0>,
#             <Reaction ACSERtex at 0x7fc036b4af70>,
#             <Reaction ACtex at 0x7fc036ae2730>,
#             <Reaction ADEtex at 0x7fc036b0ac70>,
#             <Reaction AGMtex at 0x7fc036a8ac40>,
#             <Reaction AKGtex at 0x7fc036b4aee0>,
#             <Reaction ALAALAtex at 0x7fc036b347c0>,
#             <Reaction ALAtex at 0x7fc036b0adc0>,
#             <Reaction ALLTNtex at 0x7fc036ac8880>,
#             <Reaction ALLtex at 0x7fc036ab4cd0>,
#             <Reaction AMPtex at 0x7fc036a24e20>,
#             <Reaction ANHGMtex at 0x7fc036a24b80>,
#             <Reaction ARBTtex at 0x7fc0368b42e0>,
#             <Reaction ARBtex at 0x7fc0367f1d90>,
#             <Reaction ARGtex at 0x7fc036743d30>,
#             <Reaction ASCBtex at 0x7fc0366ffa60>,
#             <Reaction ASNtex at 0x7fc03664bac0>,
#             <Reaction ASO3tex at 0x7fc0365f3dc0>,
#             <Reaction ASPtex at 0x7fc036a24e80>,
#             <Reaction BALAtex at 0x7fc0369e3f40>,
#             <Reaction BTNtex at 0x7fc0369f7d60>,
#             <Reaction BUTSO3tex at 0x7fc036a0b1c0>,
#             <Reaction BUTtex at 0x7fc0369b7af0>,
#             <Reaction CA2tex at 0x7fc0369cbd60>,
#             <Reaction CD2tex at 0x7fc03698be80>,
#             <Reaction CGLYtex at 0x7fc0369ceaf0>,
#             <Reaction CHLtex at 0x7fc036a0bc40>,
#             <Reaction CHTBStex at 0x7fc036a0b640>,
#             <Reaction CITtex at 0x7fc0369b7250>,
#             <Reaction CLBtex at 0x7fc01bb34a90>,
#             <Reaction CLtex at 0x7fc036975940>,
#             <Reaction CMPtex at 0x7fc036975c70>,
#             <Reaction CMtex at 0x7fc03698bf70>,
#             <Reaction CO2tex at 0x7fc036922eb0>,
#             <Reaction COBALT2tex at 0x7fc03698b9d0>,
#             <Reaction CRNDtex at 0x7fc0368e2e80>,
#             <Reaction CRNtex at 0x7fc0368f6940>,
#             <Reaction CSNtex at 0x7fc03688cf40>,
#             <Reaction CU2tex at 0x7fc0368b4df0>,
#             <Reaction CUtex at 0x7fc0368cbf10>,
#             <Reaction CYANtex at 0x7fc0368cbbe0>,
#             <Reaction CYNTtex at 0x7fc03685fe20>,
#             <Reaction CYSDtex at 0x7fc03685f040>,
#             <Reaction CYStex at 0x7fc03688bbb0>,
#             <Reaction CYTDtex at 0x7fc036836f70>,
#             <Reaction DALAtex at 0x7fc03688c130>,
#             <Reaction DAMPtex at 0x7fc03688cbb0>,
#             <Reaction DAPtex at 0x7fc0368a29a0>,
#             <Reaction DARBtex at 0x7fc01ba7dcd0>,
#             <Reaction DCAtex at 0x7fc03685fbb0>,
#             <Reaction DCMPtex at 0x7fc0368cbdf0>,
#             <Reaction DDGLCNtex at 0x7fc036875e50>,
#             <Reaction DGMPtex at 0x7fc03688beb0>,
#             <Reaction DGSNtex at 0x7fc03688bfd0>,
#             <Reaction DHAtex at 0x7fc036836cd0>,
#             <Reaction DIMPtex at 0x7fc0367dc8e0>,
#             <Reaction DINStex at 0x7fc0367dce20>,
#             <Reaction DMSOtex at 0x7fc036806f40>,
#             <Reaction DMStex at 0x7fc03679f7c0>,
#             <Reaction DOPAtex at 0x7fc03679fd60>,
#             <Reaction DOXRBCNtex at 0x7fc03679fdf0>,
#             <Reaction DSERtex at 0x7fc0367c1e50>,
#             <Reaction DTMPtex at 0x7fc0367c1c70>,
#             <Reaction DUMPtex at 0x7fc03676beb0>,
#             <Reaction D_LACtex at 0x7fc036847ac0>,
#             <Reaction ETHAtex at 0x7fc03672dd90>,
#             <Reaction ETHSO3tex at 0x7fc036716f40>,
#             <Reaction ETOHtex at 0x7fc03672ddc0>,
#             <Reaction F6Ptex at 0x7fc036743b80>,
#             <Reaction FALDtex at 0x7fc0366e7a60>,
#             <Reaction FE2tex at 0x7fc0366a6d30>,
#             <Reaction FE3tex at 0x7fc036622fd0>,
#             <Reaction FORtex at 0x7fc036622d30>,
#             <Reaction FRULYStex at 0x7fc036639d30>,
#             <Reaction FRUURtex at 0x7fc03664beb0>,
#             <Reaction FRUtex at 0x7fc03664bd90>,
#             <Reaction FUCtex at 0x7fc03664bf70>,
#             <Reaction FUMtex at 0x7fc0365e29d0>,
#             <Reaction FUSAtex at 0x7fc0365f3d30>,
#             <Reaction G1Ptex at 0x7fc036609af0>,
#             <Reaction G3PCtex at 0x7fc036609df0>,
#             <Reaction G3PEtex at 0x7fc03659dd60>,
#             <Reaction G3PGtex at 0x7fc03659dbb0>,
#             <Reaction G3PItex at 0x7fc03659d9a0>,
#             <Reaction G3PStex at 0x7fc0365b1a90>,
#             <Reaction G6Ptex at 0x7fc036557d60>,
#             <Reaction GAL1Ptex at 0x7fc036557f70>,
#             <Reaction GALAMtex at 0x7fc01bb34940>,
#             <Reaction GALBDtex at 0x7fc036557ee0>,
#             <Reaction GALCTNLtex at 0x7fc03656df70>,
#             <Reaction GALCTNtex at 0x7fc036582850>,
#             <Reaction GALCTtex at 0x7fc036582f40>,
#             <Reaction GALTtex at 0x7fc036516fd0>,
#             <Reaction GALURtex at 0x7fc036516af0>,
#             <Reaction GALtex at 0x7fc03653fbe0>,
#             <Reaction GAMAN6Ptex at 0x7fc03653fd60>,
#             <Reaction GAMtex at 0x7fc03653fe50>,
#             <Reaction GBBTNtex at 0x7fc03653f7f0>,
#             <Reaction GDPtex at 0x7fc0344e2ac0>,
#             <Reaction GLCNtex at 0x7fc036557e80>,
#             <Reaction GLCRtex at 0x7fc0365578e0>,
#             <Reaction GLCUR1Ptex at 0x7fc036582df0>,
#             <Reaction GLCURtex at 0x7fc036582dc0>,
#             <Reaction GLCtex_copy1 at 0x7fc036516820>,
#             <Reaction GLNtex at 0x7fc036582eb0>,
#             <Reaction GLUtex at 0x7fc0344e2d00>,
#             <Reaction GLYALDtex at 0x7fc0344e29d0>,
#             <Reaction GLYBtex at 0x7fc034478d90>,
#             <Reaction GLYC2Ptex at 0x7fc03448ee80>,
#             <Reaction GLYC3Ptex at 0x7fc0344e2eb0>,
#             <Reaction GLYCAtex at 0x7fc0365279a0>,
#             <Reaction GLYCLTtex at 0x7fc03444c2b0>,
#             <Reaction GLYCtex at 0x7fc0343c5c70>,
#             <Reaction GLYtex at 0x7fc036c9df70>,
#             <Reaction GMPtex at 0x7fc03429c1c0>,
#             <Reaction GSNtex at 0x7fc0340f0e20>,
#             <Reaction GTHOXtex at 0x7fc03412eb50>,
#             <Reaction GTHRDtex at 0x7fc0340acc10>,
#             <Reaction GTPtex at 0x7fc034018a00>,
#             <Reaction H2O2tex at 0x7fc03448e820>,
#             <Reaction H2Otex at 0x7fc03448e430>,
#             <Reaction H2Stex at 0x7fc03659d100>,
#             <Reaction H2tex at 0x7fc0344a1e20>,
#             <Reaction HCINNMtex at 0x7fc0343f0760>,
#             <Reaction HG2tex at 0x7fc03445ddc0>,
#             <Reaction HIStex at 0x7fc0343dae80>,
#             <Reaction HOMtex at 0x7fc0343ee9a0>,
#             <Reaction HPPPNtex at 0x7fc0343eeb50>,
#             <Reaction HXAtex at 0x7fc0344a1e50>,
#             <Reaction HYXNtex at 0x7fc034435790>,
#             <Reaction Htex at 0x7fc034435e50>,
#             <Reaction IDONtex at 0x7fc034405850>,
#             <Reaction ILEtex at 0x7fc03441bee0>,
#             <Reaction IMPtex at 0x7fc0343c5910>,
#             <Reaction INDOLEtex at 0x7fc0343dac40>,
#             <Reaction INSTtex at 0x7fc0343daa00>,
#             <Reaction ISETACtex at 0x7fc036d8e9d0>,
#             <Reaction Ktex at 0x7fc036dbe640>,
#             <Reaction LALADGLUtex at 0x7fc036d8aa00>,
#             <Reaction LALALGLUtex at 0x7fc036d64bb0>,
#             <Reaction LCTStex at 0x7fc036c8fac0>,
#             <Reaction LEUtex at 0x7fc036c27070>,
#             <Reaction LIPOtex at 0x7fc036b94ee0>,
#             <Reaction LYStex at 0x7fc036ba9df0>,
#             <Reaction LYXtex at 0x7fc034291850>,
#             <Reaction L_LACtex_copy1 at 0x7fc036db1eb0>,
#             <Reaction L_LACtex_copy2 at 0x7fc01bbc9c40>,
#             <Reaction MALDtex at 0x7fc03429ce80>,
#             <Reaction MALtex at 0x7fc0342afd60>,
#             <Reaction MAN6Ptex at 0x7fc034258820>,
#             <Reaction MANGLYCtex at 0x7fc03429c880>,
#             <Reaction MANtex at 0x7fc0342afe20>,
#             <Reaction MELIBtex at 0x7fc034224970>,
#             <Reaction MEOHtex at 0x7fc034224f40>,
#             <Reaction METDtex at 0x7fc0341b8df0>,
#             <Reaction METSOX1tex at 0x7fc0341cdf10>,
#             <Reaction METSOX2tex at 0x7fc0341c4af0>,
#             <Reaction METtex at 0x7fc034177880>,
#             <Reaction MG2tex at 0x7fc034177d00>,
#             <Reaction MINCYCtex at 0x7fc0341f6ca0>,
#             <Reaction MMETtex at 0x7fc0341d8e80>,
#             <Reaction MNLtex at 0x7fc034177e20>,
#             <Reaction MNtex at 0x7fc0341e4b50>,
#             <Reaction MOBDtex at 0x7fc034177f70>,
#             <Reaction MSO3tex at 0x7fc0341e4730>,
#             <Reaction N2Otex at 0x7fc03414bd90>,
#             <Reaction NACtex at 0x7fc0341a0eb0>,
#             <Reaction NAtex at 0x7fc03414b9a0>,
#             <Reaction NH4tex at 0x7fc03412efa0>,
#             <Reaction NI2tex at 0x7fc034119a30>,
#             <Reaction NMNtex at 0x7fc0340d5fa0>,
#             <Reaction NO2tex at 0x7fc0340d56a0>,
#             <Reaction NO3tex at 0x7fc034119e20>,
#             <Reaction NOtex at 0x7fc0341198e0>,
#             <Reaction O2Stex at 0x7fc03406dd30>,
#             <Reaction O2tex at 0x7fc034018e50>,
#             <Reaction OCTAtex at 0x7fc0340ac970>,
#             <Reaction ORNtex at 0x7fc034002eb0>,
#             <Reaction OROTtex at 0x7fc0340187c0>,
#             <Reaction PACALDtex at 0x7fc034018f70>,
#             <Reaction PACt1 at 0x7fc01bb48e80>,
#             <Reaction PEAMNtex at 0x7fc033fc2a90>,
#             <Reaction PENGt1 at 0x7fc01bb48ac0>,
#             <Reaction PHEtex at 0x7fc033ebce50>,
#             <Reaction PItex at 0x7fc033ebc430>,
#             <Reaction PNTOtex at 0x7fc01bb87f10>,
#             <Reaction PPALtex at 0x7fc01bb34f70>,
#             <Reaction PPAtex at 0x7fc01bb48190>,
#             <Reaction PPPNtex at 0x7fc01bb19e50>,
#             <Reaction PPTtex at 0x7fc01bb2dd00>,
#             <Reaction PROGLYtex at 0x7fc033ebc160>,
#             <Reaction PROtex at 0x7fc033ebcd60>,
#             <Reaction PSCLYStex at 0x7fc033ed1f70>,
#             <Reaction PSERtex at 0x7fc033ee4f10>,
#             <Reaction PTRCtex at 0x7fc033e39610>,
#             <Reaction PYDAMtex at 0x7fc033e4f9a0>,
#             <Reaction PYDXNtex at 0x7fc033df67c0>,
#             <Reaction PYDXtex at 0x7fc033df6550>,
#             <Reaction PYRtex at 0x7fc033ebcfd0>,
#             <Reaction QUIN2tex at 0x7fc033ed1e50>,
#             <Reaction R5Ptex at 0x7fc033e8e6a0>,
#             <Reaction RAFFtex at 0x7fc01bb87f70>,
#             <Reaction RIBtex at 0x7fc033e4fd60>,
#             <Reaction RMNtex at 0x7fc033e4fcd0>,
#             <Reaction SALCNtex at 0x7fc01bb348e0>,
#             <Reaction SBTtex at 0x7fc033ddbf70>,
#             <Reaction SELtex at 0x7fc033ddbdc0>,
#             <Reaction SERtex at 0x7fc033d40b20>,
#             <Reaction SKMtex at 0x7fc033d6aee0>,
#             <Reaction SLNTtex at 0x7fc033d6abe0>,
#             <Reaction SO2tex at 0x7fc033cffe50>,
#             <Reaction SO3tex at 0x7fc033cffa90>,
#             <Reaction SO4tex at 0x7fc033d12910>,
#             <Reaction SPMDtex at 0x7fc033e1f7c0>,
#             <Reaction SUCCtex at 0x7fc033defd30>,
#             <Reaction SUCRtex at 0x7fc033d84b20>,
#             <Reaction SULFACtex at 0x7fc033d99b50>,
#             <Reaction TARTRDtex at 0x7fc033d849a0>,
#             <Reaction TARTRtex at 0x7fc033d40970>,
#             <Reaction TAURtex at 0x7fc033d40fd0>,
#             <Reaction TCYNTtex at 0x7fc033d56eb0>,
#             <Reaction THMDtex at 0x7fc033d12e80>,
#             <Reaction THMtex at 0x7fc033d261f0>,
#             <Reaction THRPtex at 0x7fc033d26b50>,
#             <Reaction THRtex at 0x7fc01bcb8e80>,
#             <Reaction THYMtex at 0x7fc01bcb87f0>,
#             <Reaction TMAOtex at 0x7fc01bc77eb0>,
#             <Reaction TMAtex at 0x7fc01bce4df0>,
#             <Reaction TREtex at 0x7fc01bc38e80>,
#             <Reaction TRPtex at 0x7fc01bce4220>,
#             <Reaction TSULtex at 0x7fc01bc4ce20>,
#             <Reaction TTRCYCtex at 0x7fc01bc61dc0>,
#             <Reaction TUNGStex at 0x7fc01bbf4ee0>,
#             <Reaction TYMtex at 0x7fc01bbf4e20>,
#             <Reaction TYRPtex at 0x7fc01bc09d30>,
#             <Reaction TYRtex at 0x7fc01bcb8880>,
#             <Reaction UACGAMtex at 0x7fc01bccfaf0>,
#             <Reaction UDPACGALtex at 0x7fc01bccfa90>,
#             <Reaction UDPGALtex at 0x7fc01bc8cfd0>,
#             <Reaction UDPGLCURtex at 0x7fc01bc9fee0>,
#             <Reaction UDPGtex at 0x7fc01bc9f970>,
#             <Reaction UMPtex at 0x7fc01bbf4ac0>,
#             <Reaction URAtex at 0x7fc01bc09070>,
#             <Reaction UREAtex at 0x7fc01bbf49a0>,
#             <Reaction VALtex at 0x7fc01bc1eb80>,
#             <Reaction XANtex at 0x7fc01bc1ea60>,
#             <Reaction XMPtex at 0x7fc01bbb3e20>,
#             <Reaction XTSNtex at 0x7fc01bbc99d0>,
#             <Reaction XYLUtex at 0x7fc01bbc9b20>,
#             <Reaction XYLtex at 0x7fc01bbf0af0>,
#             <Reaction Zn2tex at 0x7fc01bbf05b0>})}

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

while i <1344:
   
    J= list()
    C= list()
    
    J.append(a.genes[i].name)
    C.append(a.genes[i].reactions)

    dictionary2 = dict(zip(J, C))
    dictionary.update(dictionary2)
    
    i=i+1

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7fc036d02850>,
#             <Reaction 12PPDStex at 0x7fc036d02d30>,
#             <Reaction 23CAMPtex at 0x7fc036c8f910>,
#             <Reaction 23CCMPtex at 0x7fc036c8feb0>,
#             <Reaction 23CGMPtex at 0x7fc036c8fca0>,
#             <Reaction 23CUMPtex at 0x7fc036c8ff10>,
#             <Reaction 23DAPPAtex at 0x7fc036c8f790>,
#             <Reaction 26DAHtex at 0x7fc036ca9e50>,
#             <Reaction 34dhpactex at 0x7fc036c12ac0>,
#             <Reaction 3AMPtex at 0x7fc036c12cd0>,
#             <Reaction 3CMPtex at 0x7fc036c86430>,
#             <Reaction 3GMPtex at 0x7fc036c1af10>,
#             <Reaction 3HPPtex at 0x7fc036c4a8e0>,
#             <Reaction 3PEPTtex at 0x7fc036bbbeb0>,
#             <Reaction 3UMPtex at 0x7fc036b4ff40>,
#             <Reaction 3hoxpactex at 0x7fc01bb34c10>,
#             <Reaction 4HOXPACDtex at 0x7fc036b4feb0>,
#             <Reaction 4PEPTtex at 0x7fc036b62be0>,
#             <Reaction 4hoxpactex at 0x7fc01bb34670>,
#             <Reaction 5DGLCNtex at 0x7fc036b4f610>,
#             <Reaction 5MTRtex at 0x7fc036b77e50>,
#             <Reaction 6APAt1 at 0x7fc01bb48b80>,
#             <Reaction ABUTtex at 0x7fc036bdd2b0>,
#             <Reaction ACACtex at 0x7fc036c09ee0>,
#             <Reaction ACALDtex at 0x7fc036b94190>,
#             <Reaction ACGAL1Ptex at 0x7fc036bbbdf0>,
#             <Reaction ACGALtex at 0x7fc036bbbbb0>,
#             <Reaction ACGAM1Ptex at 0x7fc036ba9d60>,
#             <Reaction ACGAtex at 0x7fc036bbbe50>,
#             <Reaction ACMANAtex at 0x7fc036b62fd0>,
#             <Reaction ACMUMtex at 0x7fc036b77ca0>,
#             <Reaction ACSERtex at 0x7fc036b4af70>,
#             <Reaction ACtex at 0x7fc036ae2730>,
#             <Reaction ADEtex at 0x7fc036b0ac70>,
#             <Reaction AGMtex at 0x7fc036a8ac40>,
#             <Reaction AKGtex at 0x7fc036b4aee0>,
#             <Reaction ALAALAtex at 0x7fc036b347c0>,
#             <Reaction ALAtex at 0x7fc036b0adc0>,
#             <Reaction ALLTNtex at 0x7fc036ac8880>,
#             <Reaction ALLtex at 0x7fc036ab4cd0>,
#             <Reaction AMPtex at 0x7fc036a24e20>,
#             <Reaction ANHGMtex at 0x7fc036a24b80>,
#             <Reaction ARBTtex at 0x7fc0368b42e0>,
#             <Reaction ARBtex at 0x7fc0367f1d90>,
#             <Reaction ARGtex at 0x7fc036743d30>,
#             <Reaction ASCBtex at 0x7fc0366ffa60>,
#             <Reaction ASNtex at 0x7fc03664bac0>,
#             <Reaction ASO3tex at 0x7fc0365f3dc0>,
#             <Reaction ASPtex at 0x7fc036a24e80>,
#             <Reaction BALAtex at 0x7fc0369e3f40>,
#             <Reaction BTNtex at 0x7fc0369f7d60>,
#             <Reaction BUTSO3tex at 0x7fc036a0b1c0>,
#             <Reaction BUTtex at 0x7fc0369b7af0>,
#             <Reaction CA2tex at 0x7fc0369cbd60>,
#             <Reaction CD2tex at 0x7fc03698be80>,
#             <Reaction CGLYtex at 0x7fc0369ceaf0>,
#             <Reaction CHLtex at 0x7fc036a0bc40>,
#             <Reaction CHTBStex at 0x7fc036a0b640>,
#             <Reaction CITtex at 0x7fc0369b7250>,
#             <Reaction CLBtex at 0x7fc01bb34a90>,
#             <Reaction CLtex at 0x7fc036975940>,
#             <Reaction CMPtex at 0x7fc036975c70>,
#             <Reaction CMtex at 0x7fc03698bf70>,
#             <Reaction CO2tex at 0x7fc036922eb0>,
#             <Reaction COBALT2tex at 0x7fc03698b9d0>,
#             <Reaction CRNDtex at 0x7fc0368e2e80>,
#             <Reaction CRNtex at 0x7fc0368f6940>,
#             <Reaction CSNtex at 0x7fc03688cf40>,
#             <Reaction CU2tex at 0x7fc0368b4df0>,
#             <Reaction CUtex at 0x7fc0368cbf10>,
#             <Reaction CYANtex at 0x7fc0368cbbe0>,
#             <Reaction CYNTtex at 0x7fc03685fe20>,
#             <Reaction CYSDtex at 0x7fc03685f040>,
#             <Reaction CYStex at 0x7fc03688bbb0>,
#             <Reaction CYTDtex at 0x7fc036836f70>,
#             <Reaction DALAtex at 0x7fc03688c130>,
#             <Reaction DAMPtex at 0x7fc03688cbb0>,
#             <Reaction DAPtex at 0x7fc0368a29a0>,
#             <Reaction DARBtex at 0x7fc01ba7dcd0>,
#             <Reaction DCAtex at 0x7fc03685fbb0>,
#             <Reaction DCMPtex at 0x7fc0368cbdf0>,
#             <Reaction DDGLCNtex at 0x7fc036875e50>,
#             <Reaction DGMPtex at 0x7fc03688beb0>,
#             <Reaction DGSNtex at 0x7fc03688bfd0>,
#             <Reaction DHAtex at 0x7fc036836cd0>,
#             <Reaction DIMPtex at 0x7fc0367dc8e0>,
#             <Reaction DINStex at 0x7fc0367dce20>,
#             <Reaction DMSOtex at 0x7fc036806f40>,
#             <Reaction DMStex at 0x7fc03679f7c0>,
#             <Reaction DOPAtex at 0x7fc03679fd60>,
#             <Reaction DOXRBCNtex at 0x7fc03679fdf0>,
#             <Reaction DSERtex at 0x7fc0367c1e50>,
#             <Reaction DTMPtex at 0x7fc0367c1c70>,
#             <Reaction DUMPtex at 0x7fc03676beb0>,
#             <Reaction D_LACtex at 0x7fc036847ac0>,
#             <Reaction ETHAtex at 0x7fc03672dd90>,
#             <Reaction ETHSO3tex at 0x7fc036716f40>,
#             <Reaction ETOHtex at 0x7fc03672ddc0>,
#             <Reaction F6Ptex at 0x7fc036743b80>,
#             <Reaction FALDtex at 0x7fc0366e7a60>,
#             <Reaction FE2tex at 0x7fc0366a6d30>,
#             <Reaction FE3tex at 0x7fc036622fd0>,
#             <Reaction FORtex at 0x7fc036622d30>,
#             <Reaction FRULYStex at 0x7fc036639d30>,
#             <Reaction FRUURtex at 0x7fc03664beb0>,
#             <Reaction FRUtex at 0x7fc03664bd90>,
#             <Reaction FUCtex at 0x7fc03664bf70>,
#             <Reaction FUMtex at 0x7fc0365e29d0>,
#             <Reaction FUSAtex at 0x7fc0365f3d30>,
#             <Reaction G1Ptex at 0x7fc036609af0>,
#             <Reaction G3PCtex at 0x7fc036609df0>,
#             <Reaction G3PEtex at 0x7fc03659dd60>,
#             <Reaction G3PGtex at 0x7fc03659dbb0>,
#             <Reaction G3PItex at 0x7fc03659d9a0>,
#             <Reaction G3PStex at 0x7fc0365b1a90>,
#             <Reaction G6Ptex at 0x7fc036557d60>,
#             <Reaction GAL1Ptex at 0x7fc036557f70>,
#             <Reaction GALAMtex at 0x7fc01bb34940>,
#             <Reaction GALBDtex at 0x7fc036557ee0>,
#             <Reaction GALCTNLtex at 0x7fc03656df70>,
#             <Reaction GALCTNtex at 0x7fc036582850>,
#             <Reaction GALCTtex at 0x7fc036582f40>,
#             <Reaction GALTtex at 0x7fc036516fd0>,
#             <Reaction GALURtex at 0x7fc036516af0>,
#             <Reaction GALtex at 0x7fc03653fbe0>,
#             <Reaction GAMAN6Ptex at 0x7fc03653fd60>,
#             <Reaction GAMtex at 0x7fc03653fe50>,
#             <Reaction GBBTNtex at 0x7fc03653f7f0>,
#             <Reaction GDPtex at 0x7fc0344e2ac0>,
#             <Reaction GLCNtex at 0x7fc036557e80>,
#             <Reaction GLCRtex at 0x7fc0365578e0>,
#             <Reaction GLCUR1Ptex at 0x7fc036582df0>,
#             <Reaction GLCURtex at 0x7fc036582dc0>,
#             <Reaction GLCtex_copy1 at 0x7fc036516820>,
#             <Reaction GLNtex at 0x7fc036582eb0>,
#             <Reaction GLUtex at 0x7fc0344e2d00>,
#             <Reaction GLYALDtex at 0x7fc0344e29d0>,
#             <Reaction GLYBtex at 0x7fc034478d90>,
#             <Reaction GLYC2Ptex at 0x7fc03448ee80>,
#             <Reaction GLYC3Ptex at 0x7fc0344e2eb0>,
#             <Reaction GLYCAtex at 0x7fc0365279a0>,
#             <Reaction GLYCLTtex at 0x7fc03444c2b0>,
#             <Reaction GLYCtex at 0x7fc0343c5c70>,
#             <Reaction GLYtex at 0x7fc036c9df70>,
#             <Reaction GMPtex at 0x7fc03429c1c0>,
#             <Reaction GSNtex at 0x7fc0340f0e20>,
#             <Reaction GTHOXtex at 0x7fc03412eb50>,
#             <Reaction GTHRDtex at 0x7fc0340acc10>,
#             <Reaction GTPtex at 0x7fc034018a00>,
#             <Reaction H2O2tex at 0x7fc03448e820>,
#             <Reaction H2Otex at 0x7fc03448e430>,
#             <Reaction H2Stex at 0x7fc03659d100>,
#             <Reaction H2tex at 0x7fc0344a1e20>,
#             <Reaction HCINNMtex at 0x7fc0343f0760>,
#             <Reaction HG2tex at 0x7fc03445ddc0>,
#             <Reaction HIStex at 0x7fc0343dae80>,
#             <Reaction HOMtex at 0x7fc0343ee9a0>,
#             <Reaction HPPPNtex at 0x7fc0343eeb50>,
#             <Reaction HXAtex at 0x7fc0344a1e50>,
#             <Reaction HYXNtex at 0x7fc034435790>,
#             <Reaction Htex at 0x7fc034435e50>,
#             <Reaction IDONtex at 0x7fc034405850>,
#             <Reaction ILEtex at 0x7fc03441bee0>,
#             <Reaction IMPtex at 0x7fc0343c5910>,
#             <Reaction INDOLEtex at 0x7fc0343dac40>,
#             <Reaction INSTtex at 0x7fc0343daa00>,
#             <Reaction ISETACtex at 0x7fc036d8e9d0>,
#             <Reaction Ktex at 0x7fc036dbe640>,
#             <Reaction LALADGLUtex at 0x7fc036d8aa00>,
#             <Reaction LALALGLUtex at 0x7fc036d64bb0>,
#             <Reaction LCTStex at 0x7fc036c8fac0>,
#             <Reaction LEUtex at 0x7fc036c27070>,
#             <Reaction LIPOtex at 0x7fc036b94ee0>,
#             <Reaction LYStex at 0x7fc036ba9df0>,
#             <Reaction LYXtex at 0x7fc034291850>,
#             <Reaction L_LACtex_copy1 at 0x7fc036db1eb0>,
#             <Reaction L_LACtex_copy2 at 0x7fc01bbc9c40>,
#             <Reaction MALDtex at 0x7fc03429ce80>,
#             <Reaction MALtex at 0x7fc0342afd60>,
#             <Reaction MAN6Ptex at 0x7fc034258820>,
#             <Reaction MANGLYCtex at 0x7fc03429c880>,
#             <Reaction MANtex at 0x7fc0342afe20>,
#             <Reaction MELIBtex at 0x7fc034224970>,
#             <Reaction MEOHtex at 0x7fc034224f40>,
#             <Reaction METDtex at 0x7fc0341b8df0>,
#             <Reaction METSOX1tex at 0x7fc0341cdf10>,
#             <Reaction METSOX2tex at 0x7fc0341c4af0>,
#             <Reaction METtex at 0x7fc034177880>,
#             <Reaction MG2tex at 0x7fc034177d00>,
#             <Reaction MINCYCtex at 0x7fc0341f6ca0>,
#             <Reaction MMETtex at 0x7fc0341d8e80>,
#             <Reaction MNLtex at 0x7fc034177e20>,
#             <Reaction MNtex at 0x7fc0341e4b50>,
#             <Reaction MOBDtex at 0x7fc034177f70>,
#             <Reaction MSO3tex at 0x7fc0341e4730>,
#             <Reaction N2Otex at 0x7fc03414bd90>,
#             <Reaction NACtex at 0x7fc0341a0eb0>,
#             <Reaction NAtex at 0x7fc03414b9a0>,
#             <Reaction NH4tex at 0x7fc03412efa0>,
#             <Reaction NI2tex at 0x7fc034119a30>,
#             <Reaction NMNtex at 0x7fc0340d5fa0>,
#             <Reaction NO2tex at 0x7fc0340d56a0>,
#             <Reaction NO3tex at 0x7fc034119e20>,
#             <Reaction NOtex at 0x7fc0341198e0>,
#             <Reaction O2Stex at 0x7fc03406dd30>,
#             <Reaction O2tex at 0x7fc034018e50>,
#             <Reaction OCTAtex at 0x7fc0340ac970>,
#             <Reaction ORNtex at 0x7fc034002eb0>,
#             <Reaction OROTtex at 0x7fc0340187c0>,
#             <Reaction PACALDtex at 0x7fc034018f70>,
#             <Reaction PACt1 at 0x7fc01bb48e80>,
#             <Reaction PEAMNtex at 0x7fc033fc2a90>,
#             <Reaction PENGt1 at 0x7fc01bb48ac0>,
#             <Reaction PHEtex at 0x7fc033ebce50>,
#             <Reaction PItex at 0x7fc033ebc430>,
#             <Reaction PNTOtex at 0x7fc01bb87f10>,
#             <Reaction PPALtex at 0x7fc01bb34f70>,
#             <Reaction PPAtex at 0x7fc01bb48190>,
#             <Reaction PPPNtex at 0x7fc01bb19e50>,
#             <Reaction PPTtex at 0x7fc01bb2dd00>,
#             <Reaction PROGLYtex at 0x7fc033ebc160>,
#             <Reaction PROtex at 0x7fc033ebcd60>,
#             <Reaction PSCLYStex at 0x7fc033ed1f70>,
#             <Reaction PSERtex at 0x7fc033ee4f10>,
#             <Reaction PTRCtex at 0x7fc033e39610>,
#             <Reaction PYDAMtex at 0x7fc033e4f9a0>,
#             <Reaction PYDXNtex at 0x7fc033df67c0>,
#             <Reaction PYDXtex at 0x7fc033df6550>,
#             <Reaction PYRtex at 0x7fc033ebcfd0>,
#             <Reaction QUIN2tex at 0x7fc033ed1e50>,
#             <Reaction R5Ptex at 0x7fc033e8e6a0>,
#             <Reaction RAFFtex at 0x7fc01bb87f70>,
#             <Reaction RIBtex at 0x7fc033e4fd60>,
#             <Reaction RMNtex at 0x7fc033e4fcd0>,
#             <Reaction SALCNtex at 0x7fc01bb348e0>,
#             <Reaction SBTtex at 0x7fc033ddbf70>,
#             <Reaction SELtex at 0x7fc033ddbdc0>,
#             <Reaction SERtex at 0x7fc033d40b20>,
#             <Reaction SKMtex at 0x7fc033d6aee0>,
#             <Reaction SLNTtex at 0x7fc033d6abe0>,
#             <Reaction SO2tex at 0x7fc033cffe50>,
#             <Reaction SO3tex at 0x7fc033cffa90>,
#             <Reaction SO4tex at 0x7fc033d12910>,
#             <Reaction SPMDtex at 0x7fc033e1f7c0>,
#             <Reaction SUCCtex at 0x7fc033defd30>,
#             <Reaction SUCRtex at 0x7fc033d84b20>,
#             <Reaction SULFACtex at 0x7fc033d99b50>,
#             <Reaction TARTRDtex at 0x7fc033d849a0>,
#             <Reaction TARTRtex at 0x7fc033d40970>,
#             <Reaction TAURtex at 0x7fc033d40fd0>,
#             <Reaction TCYNTtex at 0x7fc033d56eb0>,
#             <Reaction THMDtex at 0x7fc033d12e80>,
#             <Reaction THMtex at 0x7fc033d261f0>,
#             <Reaction THRPtex at 0x7fc033d26b50>,
#             <Reaction THRtex at 0x7fc01bcb8e80>,
#             <Reaction THYMtex at 0x7fc01bcb87f0>,
#             <Reaction TMAOtex at 0x7fc01bc77eb0>,
#             <Reaction TMAtex at 0x7fc01bce4df0>,
#             <Reaction TREtex at 0x7fc01bc38e80>,
#             <Reaction TRPtex at 0x7fc01bce4220>,
#             <Reaction TSULtex at 0x7fc01bc4ce20>,
#             <Reaction TTRCYCtex at 0x7fc01bc61dc0>,
#             <Reaction TUNGStex at 0x7fc01bbf4ee0>,
#             <Reaction TYMtex at 0x7fc01bbf4e20>,
#             <Reaction TYRPtex at 0x7fc01bc09d30>,
#             <Reaction TYRtex at 0x7fc01bcb8880>,
#             <Reaction UACGAMtex at 0x7fc01bccfaf0>,
#             <Reaction UDPACGALtex at 0x7fc01bccfa90>,
#             <Reaction UDPGALtex at 0x7fc01bc8cfd0>,
#             <Reaction UDPGLCURtex at 0x7fc01bc9fee0>,
#             <Reaction UDPGtex at 0x7fc01bc9f970>,
#             <Reaction UMPtex at 0x7fc01bbf4ac0>,
#             <Reaction URAtex at 0x7fc01bc09070>,
#             <Reaction UREAtex at 0x7fc01bbf49a0>,
#             <Reaction VALtex at 0x7fc01bc1eb80>,
#             <Reaction XANtex at 0x7fc01bc1ea60>,
#             <Reaction XMPtex at 0x7fc01bbb3e20>,
#             <Reaction XTSNtex at 0x7fc01bbc99d0>,
#             <Reaction XYLUtex at 0x7fc01bbc9b20>,
#             <Reaction XYLtex at 0x7fc01bbf0af0>,
#             <Reaction Zn2tex at 0x7fc01bbf05b0>}),
#  'YlbA': frozenset({<Reaction UGCIAMH at 0x7fc01b9faca0>}),
#  'OmpC': frozenset({<Reaction 12PPDRtex at 0x7fc036d02850>,
#             <Reaction 12PPDStex at 0x7fc036d02d30>,
#             <Reaction 23CAMPtex at 0x7fc036c8f910>,
#             <Reaction 23CCMPtex at 0x7fc036c8feb0>,
#             <Reaction 23CGMPtex at 0x7fc036c8fca0>,
#             <Reaction 23CUMPtex at 0x7fc036c8ff10>,
#             <Reaction 23DAPPAtex at 0x7fc036c8f790>,
#             <Reaction 26DAHtex at 0x7fc036ca9e50>,
#             <Reaction 34dhpactex at 0x7fc036c12ac0>,
#             <Reaction 3AMPtex at 0x7fc036c12cd0>,
#             <Reaction 3CMPtex at 0x7fc036c86430>,
#             <Reaction 3GMPtex at 0x7fc036c1af10>,
#             <Reaction 3HPPtex at 0x7fc036c4a8e0>,
#             <Reaction 3PEPTtex at 0x7fc036bbbeb0>,
#             <Reaction 3UMPtex at 0x7fc036b4ff40>,
#             <Reaction 3hoxpactex at 0x7fc01bb34c10>,
#             <Reaction 4HOXPACDtex at 0x7fc036b4feb0>,
#             <Reaction 4PEPTtex at 0x7fc036b62be0>,
#             <Reaction 4hoxpactex at 0x7fc01bb34670>,
#             <Reaction 5DGLCNtex at 0x7fc036b4f610>,
#             <Reaction 5MTRtex at 0x7fc036b77e50>,
#             <Reaction 6APAt1 at 0x7fc01bb48b80>,
#             <Reaction ABUTtex at 0x7fc036bdd2b0>,
#             <Reaction ACACtex at 0x7fc036c09ee0>,
#             <Reaction ACALDtex at 0x7fc036b94190>,
#             <Reaction ACGAL1Ptex at 0x7fc036bbbdf0>,
#             <Reaction ACGALtex at 0x7fc036bbbbb0>,
#             <Reaction ACGAM1Ptex at 0x7fc036ba9d60>,
#             <Reaction ACGAtex at 0x7fc036bbbe50>,
#             <Reaction ACMANAtex at 0x7fc036b62fd0>,
#             <Reaction ACMUMtex at 0x7fc036b77ca0>,
#             <Reaction ACNAMtex at 0x7fc036b77fd0>,
#             <Reaction ACSERtex at 0x7fc036b4af70>,
#             <Reaction ACtex at 0x7fc036ae2730>,
#             <Reaction ADEtex at 0x7fc036b0ac70>,
#             <Reaction AGMtex at 0x7fc036a8ac40>,
#             <Reaction AKGtex at 0x7fc036b4aee0>,
#             <Reaction ALAALAtex at 0x7fc036b347c0>,
#             <Reaction ALAtex at 0x7fc036b0adc0>,
#             <Reaction ALLTNtex at 0x7fc036ac8880>,
#             <Reaction ALLtex at 0x7fc036ab4cd0>,
#             <Reaction AMPtex at 0x7fc036a24e20>,
#             <Reaction ANHGMtex at 0x7fc036a24b80>,
#             <Reaction ARBTtex at 0x7fc0368b42e0>,
#             <Reaction ARBtex at 0x7fc0367f1d90>,
#             <Reaction ARGtex at 0x7fc036743d30>,
#             <Reaction ASCBtex at 0x7fc0366ffa60>,
#             <Reaction ASNtex at 0x7fc03664bac0>,
#             <Reaction ASO3tex at 0x7fc0365f3dc0>,
#             <Reaction ASPtex at 0x7fc036a24e80>,
#             <Reaction BALAtex at 0x7fc0369e3f40>,
#             <Reaction BTNtex at 0x7fc0369f7d60>,
#             <Reaction BUTSO3tex at 0x7fc036a0b1c0>,
#             <Reaction BUTtex at 0x7fc0369b7af0>,
#             <Reaction CA2tex at 0x7fc0369cbd60>,
#             <Reaction CD2tex at 0x7fc03698be80>,
#             <Reaction CGLYtex at 0x7fc0369ceaf0>,
#             <Reaction CHLtex at 0x7fc036a0bc40>,
#             <Reaction CHTBStex at 0x7fc036a0b640>,
#             <Reaction CITtex at 0x7fc0369b7250>,
#             <Reaction CLBtex at 0x7fc01bb34a90>,
#             <Reaction CLtex at 0x7fc036975940>,
#             <Reaction CMPtex at 0x7fc036975c70>,
#             <Reaction CMtex at 0x7fc03698bf70>,
#             <Reaction CO2tex at 0x7fc036922eb0>,
#             <Reaction COBALT2tex at 0x7fc03698b9d0>,
#             <Reaction CRNDtex at 0x7fc0368e2e80>,
#             <Reaction CRNtex at 0x7fc0368f6940>,
#             <Reaction CSNtex at 0x7fc03688cf40>,
#             <Reaction CU2tex at 0x7fc0368b4df0>,
#             <Reaction CUtex at 0x7fc0368cbf10>,
#             <Reaction CYANtex at 0x7fc0368cbbe0>,
#             <Reaction CYNTtex at 0x7fc03685fe20>,
#             <Reaction CYSDtex at 0x7fc03685f040>,
#             <Reaction CYStex at 0x7fc03688bbb0>,
#             <Reaction CYTDtex at 0x7fc036836f70>,
#             <Reaction DALAtex at 0x7fc03688c130>,
#             <Reaction DAMPtex at 0x7fc03688cbb0>,
#             <Reaction DAPtex at 0x7fc0368a29a0>,
#             <Reaction DARBtex at 0x7fc01ba7dcd0>,
#             <Reaction DCAtex at 0x7fc03685fbb0>,
#             <Reaction DCMPtex at 0x7fc0368cbdf0>,
#             <Reaction DDGLCNtex at 0x7fc036875e50>,
#             <Reaction DGMPtex at 0x7fc03688beb0>,
#             <Reaction DGSNtex at 0x7fc03688bfd0>,
#             <Reaction DHAtex at 0x7fc036836cd0>,
#             <Reaction DIMPtex at 0x7fc0367dc8e0>,
#             <Reaction DINStex at 0x7fc0367dce20>,
#             <Reaction DMSOtex at 0x7fc036806f40>,
#             <Reaction DMStex at 0x7fc03679f7c0>,
#             <Reaction DOPAtex at 0x7fc03679fd60>,
#             <Reaction DOXRBCNtex at 0x7fc03679fdf0>,
#             <Reaction DSERtex at 0x7fc0367c1e50>,
#             <Reaction DTMPtex at 0x7fc0367c1c70>,
#             <Reaction DUMPtex at 0x7fc03676beb0>,
#             <Reaction D_LACtex at 0x7fc036847ac0>,
#             <Reaction ETHAtex at 0x7fc03672dd90>,
#             <Reaction ETHSO3tex at 0x7fc036716f40>,
#             <Reaction ETOHtex at 0x7fc03672ddc0>,
#             <Reaction F6Ptex at 0x7fc036743b80>,
#             <Reaction FALDtex at 0x7fc0366e7a60>,
#             <Reaction FE2tex at 0x7fc0366a6d30>,
#             <Reaction FE3tex at 0x7fc036622fd0>,
#             <Reaction FORtex at 0x7fc036622d30>,
#             <Reaction FRULYStex at 0x7fc036639d30>,
#             <Reaction FRUURtex at 0x7fc03664beb0>,
#             <Reaction FRUtex at 0x7fc03664bd90>,
#             <Reaction FUCtex at 0x7fc03664bf70>,
#             <Reaction FUMtex at 0x7fc0365e29d0>,
#             <Reaction FUSAtex at 0x7fc0365f3d30>,
#             <Reaction G1Ptex at 0x7fc036609af0>,
#             <Reaction G3PCtex at 0x7fc036609df0>,
#             <Reaction G3PEtex at 0x7fc03659dd60>,
#             <Reaction G3PGtex at 0x7fc03659dbb0>,
#             <Reaction G3PItex at 0x7fc03659d9a0>,
#             <Reaction G3PStex at 0x7fc0365b1a90>,
#             <Reaction G6Ptex at 0x7fc036557d60>,
#             <Reaction GAL1Ptex at 0x7fc036557f70>,
#             <Reaction GALAMtex at 0x7fc01bb34940>,
#             <Reaction GALBDtex at 0x7fc036557ee0>,
#             <Reaction GALCTNLtex at 0x7fc03656df70>,
#             <Reaction GALCTNtex at 0x7fc036582850>,
#             <Reaction GALCTtex at 0x7fc036582f40>,
#             <Reaction GALTtex at 0x7fc036516fd0>,
#             <Reaction GALURtex at 0x7fc036516af0>,
#             <Reaction GALtex at 0x7fc03653fbe0>,
#             <Reaction GAMAN6Ptex at 0x7fc03653fd60>,
#             <Reaction GAMtex at 0x7fc03653fe50>,
#             <Reaction GBBTNtex at 0x7fc03653f7f0>,
#             <Reaction GDPtex at 0x7fc0344e2ac0>,
#             <Reaction GLCNtex at 0x7fc036557e80>,
#             <Reaction GLCRtex at 0x7fc0365578e0>,
#             <Reaction GLCUR1Ptex at 0x7fc036582df0>,
#             <Reaction GLCURtex at 0x7fc036582dc0>,
#             <Reaction GLCtex_copy1 at 0x7fc036516820>,
#             <Reaction GLNtex at 0x7fc036582eb0>,
#             <Reaction GLUtex at 0x7fc0344e2d00>,
#             <Reaction GLYALDtex at 0x7fc0344e29d0>,
#             <Reaction GLYBtex at 0x7fc034478d90>,
#             <Reaction GLYC2Ptex at 0x7fc03448ee80>,
#             <Reaction GLYC3Ptex at 0x7fc0344e2eb0>,
#             <Reaction GLYCAtex at 0x7fc0365279a0>,
#             <Reaction GLYCLTtex at 0x7fc03444c2b0>,
#             <Reaction GLYCtex at 0x7fc0343c5c70>,
#             <Reaction GLYtex at 0x7fc036c9df70>,
#             <Reaction GMPtex at 0x7fc03429c1c0>,
#             <Reaction GSNtex at 0x7fc0340f0e20>,
#             <Reaction GTHOXtex at 0x7fc03412eb50>,
#             <Reaction GTHRDtex at 0x7fc0340acc10>,
#             <Reaction GTPtex at 0x7fc034018a00>,
#             <Reaction H2O2tex at 0x7fc03448e820>,
#             <Reaction H2Otex at 0x7fc03448e430>,
#             <Reaction H2Stex at 0x7fc03659d100>,
#             <Reaction H2tex at 0x7fc0344a1e20>,
#             <Reaction HCINNMtex at 0x7fc0343f0760>,
#             <Reaction HG2tex at 0x7fc03445ddc0>,
#             <Reaction HIStex at 0x7fc0343dae80>,
#             <Reaction HOMtex at 0x7fc0343ee9a0>,
#             <Reaction HPPPNtex at 0x7fc0343eeb50>,
#             <Reaction HXAtex at 0x7fc0344a1e50>,
#             <Reaction HYXNtex at 0x7fc034435790>,
#             <Reaction Htex at 0x7fc034435e50>,
#             <Reaction IDONtex at 0x7fc034405850>,
#             <Reaction ILEtex at 0x7fc03441bee0>,
#             <Reaction IMPtex at 0x7fc0343c5910>,
#             <Reaction INDOLEtex at 0x7fc0343dac40>,
#             <Reaction INSTtex at 0x7fc0343daa00>,
#             <Reaction ISETACtex at 0x7fc036d8e9d0>,
#             <Reaction Ktex at 0x7fc036dbe640>,
#             <Reaction LALADGLUtex at 0x7fc036d8aa00>,
#             <Reaction LALALGLUtex at 0x7fc036d64bb0>,
#             <Reaction LCTStex at 0x7fc036c8fac0>,
#             <Reaction LEUtex at 0x7fc036c27070>,
#             <Reaction LIPOtex at 0x7fc036b94ee0>,
#             <Reaction LYStex at 0x7fc036ba9df0>,
#             <Reaction LYXtex at 0x7fc034291850>,
#             <Reaction L_LACtex_copy1 at 0x7fc036db1eb0>,
#             <Reaction L_LACtex_copy2 at 0x7fc01bbc9c40>,
#             <Reaction MALDtex at 0x7fc03429ce80>,
#             <Reaction MALtex at 0x7fc0342afd60>,
#             <Reaction MAN6Ptex at 0x7fc034258820>,
#             <Reaction MANGLYCtex at 0x7fc03429c880>,
#             <Reaction MANtex at 0x7fc0342afe20>,
#             <Reaction MELIBtex at 0x7fc034224970>,
#             <Reaction MEOHtex at 0x7fc034224f40>,
#             <Reaction METDtex at 0x7fc0341b8df0>,
#             <Reaction METSOX1tex at 0x7fc0341cdf10>,
#             <Reaction METSOX2tex at 0x7fc0341c4af0>,
#             <Reaction METtex at 0x7fc034177880>,
#             <Reaction MG2tex at 0x7fc034177d00>,
#             <Reaction MINCYCtex at 0x7fc0341f6ca0>,
#             <Reaction MMETtex at 0x7fc0341d8e80>,
#             <Reaction MNLtex at 0x7fc034177e20>,
#             <Reaction MNtex at 0x7fc0341e4b50>,
#             <Reaction MOBDtex at 0x7fc034177f70>,
#             <Reaction MSO3tex at 0x7fc0341e4730>,
#             <Reaction N2Otex at 0x7fc03414bd90>,
#             <Reaction NACtex at 0x7fc0341a0eb0>,
#             <Reaction NAtex at 0x7fc03414b9a0>,
#             <Reaction NH4tex at 0x7fc03412efa0>,
#             <Reaction NI2tex at 0x7fc034119a30>,
#             <Reaction NMNtex at 0x7fc0340d5fa0>,
#             <Reaction NO2tex at 0x7fc0340d56a0>,
#             <Reaction NO3tex at 0x7fc034119e20>,
#             <Reaction NOtex at 0x7fc0341198e0>,
#             <Reaction O2Stex at 0x7fc03406dd30>,
#             <Reaction O2tex at 0x7fc034018e50>,
#             <Reaction OCTAtex at 0x7fc0340ac970>,
#             <Reaction ORNtex at 0x7fc034002eb0>,
#             <Reaction OROTtex at 0x7fc0340187c0>,
#             <Reaction PACALDtex at 0x7fc034018f70>,
#             <Reaction PACt1 at 0x7fc01bb48e80>,
#             <Reaction PEAMNtex at 0x7fc033fc2a90>,
#             <Reaction PENGt1 at 0x7fc01bb48ac0>,
#             <Reaction PHEtex at 0x7fc033ebce50>,
#             <Reaction PItex at 0x7fc033ebc430>,
#             <Reaction PNTOtex at 0x7fc01bb87f10>,
#             <Reaction PPALtex at 0x7fc01bb34f70>,
#             <Reaction PPAtex at 0x7fc01bb48190>,
#             <Reaction PPPNtex at 0x7fc01bb19e50>,
#             <Reaction PPTtex at 0x7fc01bb2dd00>,
#             <Reaction PROGLYtex at 0x7fc033ebc160>,
#             <Reaction PROtex at 0x7fc033ebcd60>,
#             <Reaction PSCLYStex at 0x7fc033ed1f70>,
#             <Reaction PSERtex at 0x7fc033ee4f10>,
#             <Reaction PTRCtex at 0x7fc033e39610>,
#             <Reaction PYDAMtex at 0x7fc033e4f9a0>,
#             <Reaction PYDXNtex at 0x7fc033df67c0>,
#             <Reaction PYDXtex at 0x7fc033df6550>,
#             <Reaction PYRtex at 0x7fc033ebcfd0>,
#             <Reaction QUIN2tex at 0x7fc033ed1e50>,
#             <Reaction R5Ptex at 0x7fc033e8e6a0>,
#             <Reaction RAFFtex at 0x7fc01bb87f70>,
#             <Reaction RIBtex at 0x7fc033e4fd60>,
#             <Reaction RMNtex at 0x7fc033e4fcd0>,
#             <Reaction SALCNtex at 0x7fc01bb348e0>,
#             <Reaction SBTtex at 0x7fc033ddbf70>,
#             <Reaction SELtex at 0x7fc033ddbdc0>,
#             <Reaction SERtex at 0x7fc033d40b20>,
#             <Reaction SKMtex at 0x7fc033d6aee0>,
#             <Reaction SLNTtex at 0x7fc033d6abe0>,
#             <Reaction SO2tex at 0x7fc033cffe50>,
#             <Reaction SO3tex at 0x7fc033cffa90>,
#             <Reaction SO4tex at 0x7fc033d12910>,
#             <Reaction SPMDtex at 0x7fc033e1f7c0>,
#             <Reaction SUCCtex at 0x7fc033defd30>,
#             <Reaction SUCRtex at 0x7fc033d84b20>,
#             <Reaction SULFACtex at 0x7fc033d99b50>,
#             <Reaction TARTRDtex at 0x7fc033d849a0>,
#             <Reaction TARTRtex at 0x7fc033d40970>,
#             <Reaction TAURtex at 0x7fc033d40fd0>,
#             <Reaction TCYNTtex at 0x7fc033d56eb0>,
#             <Reaction THMDtex at 0x7fc033d12e80>,
#             <Reaction THMtex at 0x7fc033d261f0>,
#             <Reaction THRPtex at 0x7fc033d26b50>,
#             <Reaction THRtex at 0x7fc01bcb8e80>,
#             <Reaction THYMtex at 0x7fc01bcb87f0>,
#             <Reaction TMAOtex at 0x7fc01bc77eb0>,
#             <Reaction TMAtex at 0x7fc01bce4df0>,
#             <Reaction TREtex at 0x7fc01bc38e80>,
#             <Reaction TRPtex at 0x7fc01bce4220>,
#             <Reaction TSULtex at 0x7fc01bc4ce20>,
#             <Reaction TTRCYCtex at 0x7fc01bc61dc0>,
#             <Reaction TUNGStex at 0x7fc01bbf4ee0>,
#             <Reaction TYMtex at 0x7fc01bbf4e20>,
#             <Reaction TYRPtex at 0x7fc01bc09d30>,
#             <Reaction TYRtex at 0x7fc01bcb8880>,
#             <Reaction UACGAMtex at 0x7fc01bccfaf0>,
#             <Reaction UDPACGALtex at 0x7fc01bccfa90>,
#             <Reaction UDPGALtex at 0x7fc01bc8cfd0>,
#             <Reaction UDPGLCURtex at 0x7fc01bc9fee0>,
#             <Reaction UDPGtex at 0x7fc01bc9f970>,
#             <Reaction UMPtex at 0x7fc01bbf4ac0>,
#             <Reaction URAtex at 0x7fc01bc09070>,
#             <Reaction UREAtex at 0x7fc01bbf49a0>,
#             <Reaction VALtex at 0x7fc01bc1eb80>,
#             <Reaction XANtex at 0x7fc01bc1ea60>,
#             <Reaction XMPtex at 0x7fc01bbb3e20>,
#             <Reaction XTSNtex at 0x7fc01bbc99d0>,
#             <Reaction XYLUtex at 0x7fc01bbc9b20>,
#             <Reaction XYLtex at 0x7fc01bbf0af0>,
#             <Reaction Zn2tex at 0x7fc01bbf05b0>}),
#  'OmpF': frozenset({<Reaction 12PPDRtex at 0x7fc036d02850>,
#             <Reaction 12PPDStex at 0x7fc036d02d30>,
#             <Reaction 23CAMPtex at 0x7fc036c8f910>,
#             <Reaction 23CCMPtex at 0x7fc036c8feb0>,
#             <Reaction 23CGMPtex at 0x7fc036c8fca0>,
#             <Reaction 23CUMPtex at 0x7fc036c8ff10>,
#             <Reaction 23DAPPAtex at 0x7fc036c8f790>,
#             <Reaction 26DAHtex at 0x7fc036ca9e50>,
#             <Reaction 34dhpactex at 0x7fc036c12ac0>,
#             <Reaction 3AMPtex at 0x7fc036c12cd0>,
#             <Reaction 3CMPtex at 0x7fc036c86430>,
#             <Reaction 3GMPtex at 0x7fc036c1af10>,
#             <Reaction 3HPPtex at 0x7fc036c4a8e0>,
#             <Reaction 3PEPTtex at 0x7fc036bbbeb0>,
#             <Reaction 3UMPtex at 0x7fc036b4ff40>,
#             <Reaction 3hoxpactex at 0x7fc01bb34c10>,
#             <Reaction 4HOXPACDtex at 0x7fc036b4feb0>,
#             <Reaction 4PEPTtex at 0x7fc036b62be0>,
#             <Reaction 4hoxpactex at 0x7fc01bb34670>,
#             <Reaction 5DGLCNtex at 0x7fc036b4f610>,
#             <Reaction 5MTRtex at 0x7fc036b77e50>,
#             <Reaction 6APAt1 at 0x7fc01bb48b80>,
#             <Reaction ABUTtex at 0x7fc036bdd2b0>,
#             <Reaction ACACtex at 0x7fc036c09ee0>,
#             <Reaction ACALDtex at 0x7fc036b94190>,
#             <Reaction ACGAL1Ptex at 0x7fc036bbbdf0>,
#             <Reaction ACGALtex at 0x7fc036bbbbb0>,
#             <Reaction ACGAM1Ptex at 0x7fc036ba9d60>,
#             <Reaction ACGAtex at 0x7fc036bbbe50>,
#             <Reaction ACMANAtex at 0x7fc036b62fd0>,
#             <Reaction ACMUMtex at 0x7fc036b77ca0>,
#             <Reaction ACNAMtex at 0x7fc036b77fd0>,
#             <Reaction ACSERtex at 0x7fc036b4af70>,
#             <Reaction ACtex at 0x7fc036ae2730>,
#             <Reaction ADEtex at 0x7fc036b0ac70>,
#             <Reaction AGMtex at 0x7fc036a8ac40>,
#             <Reaction AKGtex at 0x7fc036b4aee0>,
#             <Reaction ALAALAtex at 0x7fc036b347c0>,
#             <Reaction ALAtex at 0x7fc036b0adc0>,
#             <Reaction ALLTNtex at 0x7fc036ac8880>,
#             <Reaction ALLtex at 0x7fc036ab4cd0>,
#             <Reaction AMPtex at 0x7fc036a24e20>,
#             <Reaction ANHGMtex at 0x7fc036a24b80>,
#             <Reaction ARBTtex at 0x7fc0368b42e0>,
#             <Reaction ARBtex at 0x7fc0367f1d90>,
#             <Reaction ARGtex at 0x7fc036743d30>,
#             <Reaction ASCBtex at 0x7fc0366ffa60>,
#             <Reaction ASNtex at 0x7fc03664bac0>,
#             <Reaction ASO3tex at 0x7fc0365f3dc0>,
#             <Reaction ASPtex at 0x7fc036a24e80>,
#             <Reaction BALAtex at 0x7fc0369e3f40>,
#             <Reaction BTNtex at 0x7fc0369f7d60>,
#             <Reaction BUTSO3tex at 0x7fc036a0b1c0>,
#             <Reaction BUTtex at 0x7fc0369b7af0>,
#             <Reaction CA2tex at 0x7fc0369cbd60>,
#             <Reaction CD2tex at 0x7fc03698be80>,
#             <Reaction CGLYtex at 0x7fc0369ceaf0>,
#             <Reaction CHLtex at 0x7fc036a0bc40>,
#             <Reaction CHTBStex at 0x7fc036a0b640>,
#             <Reaction CITtex at 0x7fc0369b7250>,
#             <Reaction CLBtex at 0x7fc01bb34a90>,
#             <Reaction CLtex at 0x7fc036975940>,
#             <Reaction CMPtex at 0x7fc036975c70>,
#             <Reaction CMtex at 0x7fc03698bf70>,
#             <Reaction CO2tex at 0x7fc036922eb0>,
#             <Reaction COBALT2tex at 0x7fc03698b9d0>,
#             <Reaction CRNDtex at 0x7fc0368e2e80>,
#             <Reaction CRNtex at 0x7fc0368f6940>,
#             <Reaction CSNtex at 0x7fc03688cf40>,
#             <Reaction CU2tex at 0x7fc0368b4df0>,
#             <Reaction CUtex at 0x7fc0368cbf10>,
#             <Reaction CYANtex at 0x7fc0368cbbe0>,
#             <Reaction CYNTtex at 0x7fc03685fe20>,
#             <Reaction CYSDtex at 0x7fc03685f040>,
#             <Reaction CYStex at 0x7fc03688bbb0>,
#             <Reaction CYTDtex at 0x7fc036836f70>,
#             <Reaction DALAtex at 0x7fc03688c130>,
#             <Reaction DAMPtex at 0x7fc03688cbb0>,
#             <Reaction DAPtex at 0x7fc0368a29a0>,
#             <Reaction DARBtex at 0x7fc01ba7dcd0>,
#             <Reaction DCAtex at 0x7fc03685fbb0>,
#             <Reaction DCMPtex at 0x7fc0368cbdf0>,
#             <Reaction DDGLCNtex at 0x7fc036875e50>,
#             <Reaction DGMPtex at 0x7fc03688beb0>,
#             <Reaction DGSNtex at 0x7fc03688bfd0>,
#             <Reaction DHAtex at 0x7fc036836cd0>,
#             <Reaction DIMPtex at 0x7fc0367dc8e0>,
#             <Reaction DINStex at 0x7fc0367dce20>,
#             <Reaction DMSOtex at 0x7fc036806f40>,
#             <Reaction DMStex at 0x7fc03679f7c0>,
#             <Reaction DOPAtex at 0x7fc03679fd60>,
#             <Reaction DOXRBCNtex at 0x7fc03679fdf0>,
#             <Reaction DSERtex at 0x7fc0367c1e50>,
#             <Reaction DTMPtex at 0x7fc0367c1c70>,
#             <Reaction DUMPtex at 0x7fc03676beb0>,
#             <Reaction D_LACtex at 0x7fc036847ac0>,
#             <Reaction ETHAtex at 0x7fc03672dd90>,
#             <Reaction ETHSO3tex at 0x7fc036716f40>,
#             <Reaction ETOHtex at 0x7fc03672ddc0>,
#             <Reaction F6Ptex at 0x7fc036743b80>,
#             <Reaction FALDtex at 0x7fc0366e7a60>,
#             <Reaction FE2tex at 0x7fc0366a6d30>,
#             <Reaction FE3tex at 0x7fc036622fd0>,
#             <Reaction FORtex at 0x7fc036622d30>,
#             <Reaction FRULYStex at 0x7fc036639d30>,
#             <Reaction FRUURtex at 0x7fc03664beb0>,
#             <Reaction FRUtex at 0x7fc03664bd90>,
#             <Reaction FUCtex at 0x7fc03664bf70>,
#             <Reaction FUMtex at 0x7fc0365e29d0>,
#             <Reaction FUSAtex at 0x7fc0365f3d30>,
#             <Reaction G1Ptex at 0x7fc036609af0>,
#             <Reaction G3PCtex at 0x7fc036609df0>,
#             <Reaction G3PEtex at 0x7fc03659dd60>,
#             <Reaction G3PGtex at 0x7fc03659dbb0>,
#             <Reaction G3PItex at 0x7fc03659d9a0>,
#             <Reaction G3PStex at 0x7fc0365b1a90>,
#             <Reaction G6Ptex at 0x7fc036557d60>,
#             <Reaction GAL1Ptex at 0x7fc036557f70>,
#             <Reaction GALAMtex at 0x7fc01bb34940>,
#             <Reaction GALBDtex at 0x7fc036557ee0>,
#             <Reaction GALCTNLtex at 0x7fc03656df70>,
#             <Reaction GALCTNtex at 0x7fc036582850>,
#             <Reaction GALCTtex at 0x7fc036582f40>,
#             <Reaction GALTtex at 0x7fc036516fd0>,
#             <Reaction GALURtex at 0x7fc036516af0>,
#             <Reaction GALtex at 0x7fc03653fbe0>,
#             <Reaction GAMAN6Ptex at 0x7fc03653fd60>,
#             <Reaction GAMtex at 0x7fc03653fe50>,
#             <Reaction GBBTNtex at 0x7fc03653f7f0>,
#             <Reaction GDPtex at 0x7fc0344e2ac0>,
#             <Reaction GLCNtex at 0x7fc036557e80>,
#             <Reaction GLCRtex at 0x7fc0365578e0>,
#             <Reaction GLCUR1Ptex at 0x7fc036582df0>,
#             <Reaction GLCURtex at 0x7fc036582dc0>,
#             <Reaction GLCtex_copy1 at 0x7fc036516820>,
#             <Reaction GLNtex at 0x7fc036582eb0>,
#             <Reaction GLUtex at 0x7fc0344e2d00>,
#             <Reaction GLYALDtex at 0x7fc0344e29d0>,
#             <Reaction GLYBtex at 0x7fc034478d90>,
#             <Reaction GLYC2Ptex at 0x7fc03448ee80>,
#             <Reaction GLYC3Ptex at 0x7fc0344e2eb0>,
#             <Reaction GLYCAtex at 0x7fc0365279a0>,
#             <Reaction GLYCLTtex at 0x7fc03444c2b0>,
#             <Reaction GLYCtex at 0x7fc0343c5c70>,
#             <Reaction GLYtex at 0x7fc036c9df70>,
#             <Reaction GMPtex at 0x7fc03429c1c0>,
#             <Reaction GSNtex at 0x7fc0340f0e20>,
#             <Reaction GTHOXtex at 0x7fc03412eb50>,
#             <Reaction GTHRDtex at 0x7fc0340acc10>,
#             <Reaction GTPtex at 0x7fc034018a00>,
#             <Reaction H2O2tex at 0x7fc03448e820>,
#             <Reaction H2Otex at 0x7fc03448e430>,
#             <Reaction H2Stex at 0x7fc03659d100>,
#             <Reaction H2tex at 0x7fc0344a1e20>,
#             <Reaction HCINNMtex at 0x7fc0343f0760>,
#             <Reaction HG2tex at 0x7fc03445ddc0>,
#             <Reaction HIStex at 0x7fc0343dae80>,
#             <Reaction HOMtex at 0x7fc0343ee9a0>,
#             <Reaction HPPPNtex at 0x7fc0343eeb50>,
#             <Reaction HXAtex at 0x7fc0344a1e50>,
#             <Reaction HYXNtex at 0x7fc034435790>,
#             <Reaction Htex at 0x7fc034435e50>,
#             <Reaction IDONtex at 0x7fc034405850>,
#             <Reaction ILEtex at 0x7fc03441bee0>,
#             <Reaction IMPtex at 0x7fc0343c5910>,
#             <Reaction INDOLEtex at 0x7fc0343dac40>,
#             <Reaction INSTtex at 0x7fc0343daa00>,
#             <Reaction ISETACtex at 0x7fc036d8e9d0>,
#             <Reaction Ktex at 0x7fc036dbe640>,
#             <Reaction LALADGLUtex at 0x7fc036d8aa00>,
#             <Reaction LALALGLUtex at 0x7fc036d64bb0>,
#             <Reaction LCTStex at 0x7fc036c8fac0>,
#             <Reaction LEUtex at 0x7fc036c27070>,
#             <Reaction LIPOtex at 0x7fc036b94ee0>,
#             <Reaction LYStex at 0x7fc036ba9df0>,
#             <Reaction LYXtex at 0x7fc034291850>,
#             <Reaction L_LACtex_copy1 at 0x7fc036db1eb0>,
#             <Reaction L_LACtex_copy2 at 0x7fc01bbc9c40>,
#             <Reaction MALDtex at 0x7fc03429ce80>,
#             <Reaction MALtex at 0x7fc0342afd60>,
#             <Reaction MAN6Ptex at 0x7fc034258820>,
#             <Reaction MANGLYCtex at 0x7fc03429c880>,
#             <Reaction MANtex at 0x7fc0342afe20>,
#             <Reaction MELIBtex at 0x7fc034224970>,
#             <Reaction MEOHtex at 0x7fc034224f40>,
#             <Reaction METDtex at 0x7fc0341b8df0>,
#             <Reaction METSOX1tex at 0x7fc0341cdf10>,
#             <Reaction METSOX2tex at 0x7fc0341c4af0>,
#             <Reaction METtex at 0x7fc034177880>,
#             <Reaction MG2tex at 0x7fc034177d00>,
#             <Reaction MINCYCtex at 0x7fc0341f6ca0>,
#             <Reaction MMETtex at 0x7fc0341d8e80>,
#             <Reaction MNLtex at 0x7fc034177e20>,
#             <Reaction MNtex at 0x7fc0341e4b50>,
#             <Reaction MOBDtex at 0x7fc034177f70>,
#             <Reaction MSO3tex at 0x7fc0341e4730>,
#             <Reaction N2Otex at 0x7fc03414bd90>,
#             <Reaction NACtex at 0x7fc0341a0eb0>,
#             <Reaction NAtex at 0x7fc03414b9a0>,
#             <Reaction NH4tex at 0x7fc03412efa0>,
#             <Reaction NI2tex at 0x7fc034119a30>,
#             <Reaction NMNtex at 0x7fc0340d5fa0>,
#             <Reaction NO2tex at 0x7fc0340d56a0>,
#             <Reaction NO3tex at 0x7fc034119e20>,
#             <Reaction NOtex at 0x7fc0341198e0>,
#             <Reaction O2Stex at 0x7fc03406dd30>,
#             <Reaction O2tex at 0x7fc034018e50>,
#             <Reaction OCTAtex at 0x7fc0340ac970>,
#             <Reaction ORNtex at 0x7fc034002eb0>,
#             <Reaction OROTtex at 0x7fc0340187c0>,
#             <Reaction PACALDtex at 0x7fc034018f70>,
#             <Reaction PACt1 at 0x7fc01bb48e80>,
#             <Reaction PEAMNtex at 0x7fc033fc2a90>,
#             <Reaction PENGt1 at 0x7fc01bb48ac0>,
#             <Reaction PHEtex at 0x7fc033ebce50>,
#             <Reaction PItex at 0x7fc033ebc430>,
#             <Reaction PNTOtex at 0x7fc01bb87f10>,
#             <Reaction PPALtex at 0x7fc01bb34f70>,
#             <Reaction PPAtex at 0x7fc01bb48190>,
#             <Reaction PPPNtex at 0x7fc01bb19e50>,
#             <Reaction PPTtex at 0x7fc01bb2dd00>,
#             <Reaction PROGLYtex at 0x7fc033ebc160>,
#             <Reaction PROtex at 0x7fc033ebcd60>,
#             <Reaction PSCLYStex at 0x7fc033ed1f70>,
#             <Reaction PSERtex at 0x7fc033ee4f10>,
#             <Reaction PTRCtex at 0x7fc033e39610>,
#             <Reaction PYDAMtex at 0x7fc033e4f9a0>,
#             <Reaction PYDXNtex at 0x7fc033df67c0>,
#             <Reaction PYDXtex at 0x7fc033df6550>,
#             <Reaction PYRtex at 0x7fc033ebcfd0>,
#             <Reaction QUIN2tex at 0x7fc033ed1e50>,
#             <Reaction R5Ptex at 0x7fc033e8e6a0>,
#             <Reaction RAFFtex at 0x7fc01bb87f70>,
#             <Reaction RIBtex at 0x7fc033e4fd60>,
#             <Reaction RMNtex at 0x7fc033e4fcd0>,
#             <Reaction SALCNtex at 0x7fc01bb348e0>,
#             <Reaction SBTtex at 0x7fc033ddbf70>,
#             <Reaction SELtex at 0x7fc033ddbdc0>,
#             <Reaction SERtex at 0x7fc033d40b20>,
#             <Reaction SKMtex at 0x7fc033d6aee0>,
#             <Reaction SLNTtex at 0x7fc033d6abe0>,
#             <Reaction SO2tex at 0x7fc033cffe50>,
#             <Reaction SO3tex at 0x7fc033cffa90>,
#             <Reaction SO4tex at 0x7fc033d12910>,
#             <Reaction SPMDtex at 0x7fc033e1f7c0>,
#             <Reaction SUCCtex at 0x7fc033defd30>,
#             <Reaction SUCRtex at 0x7fc033d84b20>,
#             <Reaction SULFACtex at 0x7fc033d99b50>,
#             <Reaction TARTRDtex at 0x7fc033d849a0>,
#             <Reaction TARTRtex at 0x7fc033d40970>,
#             <Reaction TAURtex at 0x7fc033d40fd0>,
#             <Reaction TCYNTtex at 0x7fc033d56eb0>,
#             <Reaction THMDtex at 0x7fc033d12e80>,
#             <Reaction THMtex at 0x7fc033d261f0>,
#             <Reaction THRPtex at 0x7fc033d26b50>,
#             <Reaction THRtex at 0x7fc01bcb8e80>,
#             <Reaction THYMtex at 0x7fc01bcb87f0>,
#             <Reaction TMAOtex at 0x7fc01bc77eb0>,
#             <Reaction TMAtex at 0x7fc01bce4df0>,
#             <Reaction TREtex at 0x7fc01bc38e80>,
#             <Reaction TRPtex at 0x7fc01bce4220>,
#             <Reaction TSULtex at 0x7fc01bc4ce20>,
#             <Reaction TTRCYCtex at 0x7fc01bc61dc0>,
#             <Reaction TUNGStex at 0x7fc01bbf4ee0>,
#             <Reaction TYMtex at 0x7fc01bbf4e20>,
#             <Reaction TYRPtex at 0x7fc01bc09d30>,
#             <Reaction TYRtex at 0x7fc01bcb8880>,
#             <Reaction UACGAMtex at 0x7fc01bccfaf0>,
#             <Reaction UDPACGALtex at 0x7fc01bccfa90>,
#             <Reaction UDPGALtex at 0x7fc01bc8cfd0>,
#             <Reaction UDPGLCURtex at 0x7fc01bc9fee0>,
#             <Reaction UDPGtex at 0x7fc01bc9f970>,
#             <Reaction UMPtex at 0x7fc01bbf4ac0>,
#             <Reaction URAtex at 0x7fc01bc09070>,
#             <Reaction UREAtex at 0x7fc01bbf49a0>,
#             <Reaction VALtex at 0x7fc01bc1eb80>,
#             <Reaction XANtex at 0x7fc01bc1ea60>,
#             <Reaction XMPtex at 0x7fc01bbb3e20>,
#             <Reaction XTSNtex at 0x7fc01bbc99d0>,
#             <Reaction XYLUtex at 0x7fc01bbc9b20>,
#             <Reaction XYLtex at 0x7fc01bbf0af0>,
#             <Reaction Zn2tex at 0x7fc01bbf05b0>}),
#  'OmpN': frozenset({<Reaction 12PPDRtex at 0x7fc036d02850>,
#             <Reaction 12PPDStex at 0x7fc036d02d30>,
#             <Reaction 23CAMPtex at 0x7fc036c8f910>,
#             <Reaction 23CCMPtex at 0x7fc036c8feb0>,
#             <Reaction 23CGMPtex at 0x7fc036c8fca0>,
#             <Reaction 23CUMPtex at 0x7fc036c8ff10>,
#             <Reaction 23DAPPAtex at 0x7fc036c8f790>,
#             <Reaction 26DAHtex at 0x7fc036ca9e50>,
#             <Reaction 34dhpactex at 0x7fc036c12ac0>,
#             <Reaction 3AMPtex at 0x7fc036c12cd0>,
#             <Reaction 3CMPtex at 0x7fc036c86430>,
#             <Reaction 3GMPtex at 0x7fc036c1af10>,
#             <Reaction 3HPPtex at 0x7fc036c4a8e0>,
#             <Reaction 3PEPTtex at 0x7fc036bbbeb0>,
#             <Reaction 3UMPtex at 0x7fc036b4ff40>,
#             <Reaction 3hoxpactex at 0x7fc01bb34c10>,
#             <Reaction 4HOXPACDtex at 0x7fc036b4feb0>,
#             <Reaction 4PEPTtex at 0x7fc036b62be0>,
#             <Reaction 4hoxpactex at 0x7fc01bb34670>,
#             <Reaction 5DGLCNtex at 0x7fc036b4f610>,
#             <Reaction 5MTRtex at 0x7fc036b77e50>,
#             <Reaction 6APAt1 at 0x7fc01bb48b80>,
#             <Reaction ABUTtex at 0x7fc036bdd2b0>,
#             <Reaction ACACtex at 0x7fc036c09ee0>,
#             <Reaction ACALDtex at 0x7fc036b94190>,
#             <Reaction ACGAL1Ptex at 0x7fc036bbbdf0>,
#             <Reaction ACGALtex at 0x7fc036bbbbb0>,
#             <Reaction ACGAM1Ptex at 0x7fc036ba9d60>,
#             <Reaction ACGAtex at 0x7fc036bbbe50>,
#             <Reaction ACMANAtex at 0x7fc036b62fd0>,
#             <Reaction ACMUMtex at 0x7fc036b77ca0>,
#             <Reaction ACSERtex at 0x7fc036b4af70>,
#             <Reaction ACtex at 0x7fc036ae2730>,
#             <Reaction ADEtex at 0x7fc036b0ac70>,
#             <Reaction AGMtex at 0x7fc036a8ac40>,
#             <Reaction AKGtex at 0x7fc036b4aee0>,
#             <Reaction ALAALAtex at 0x7fc036b347c0>,
#             <Reaction ALAtex at 0x7fc036b0adc0>,
#             <Reaction ALLTNtex at 0x7fc036ac8880>,
#             <Reaction ALLtex at 0x7fc036ab4cd0>,
#             <Reaction AMPtex at 0x7fc036a24e20>,
#             <Reaction ANHGMtex at 0x7fc036a24b80>,
#             <Reaction ARBTtex at 0x7fc0368b42e0>,
#             <Reaction ARBtex at 0x7fc0367f1d90>,
#             <Reaction ARGtex at 0x7fc036743d30>,
#             <Reaction ASCBtex at 0x7fc0366ffa60>,
#             <Reaction ASNtex at 0x7fc03664bac0>,
#             <Reaction ASO3tex at 0x7fc0365f3dc0>,
#             <Reaction ASPtex at 0x7fc036a24e80>,
#             <Reaction BALAtex at 0x7fc0369e3f40>,
#             <Reaction BTNtex at 0x7fc0369f7d60>,
#             <Reaction BUTSO3tex at 0x7fc036a0b1c0>,
#             <Reaction BUTtex at 0x7fc0369b7af0>,
#             <Reaction CA2tex at 0x7fc0369cbd60>,
#             <Reaction CD2tex at 0x7fc03698be80>,
#             <Reaction CGLYtex at 0x7fc0369ceaf0>,
#             <Reaction CHLtex at 0x7fc036a0bc40>,
#             <Reaction CHTBStex at 0x7fc036a0b640>,
#             <Reaction CITtex at 0x7fc0369b7250>,
#             <Reaction CLBtex at 0x7fc01bb34a90>,
#             <Reaction CLtex at 0x7fc036975940>,
#             <Reaction CMPtex at 0x7fc036975c70>,
#             <Reaction CMtex at 0x7fc03698bf70>,
#             <Reaction CO2tex at 0x7fc036922eb0>,
#             <Reaction COBALT2tex at 0x7fc03698b9d0>,
#             <Reaction CRNDtex at 0x7fc0368e2e80>,
#             <Reaction CRNtex at 0x7fc0368f6940>,
#             <Reaction CSNtex at 0x7fc03688cf40>,
#             <Reaction CU2tex at 0x7fc0368b4df0>,
#             <Reaction CUtex at 0x7fc0368cbf10>,
#             <Reaction CYANtex at 0x7fc0368cbbe0>,
#             <Reaction CYNTtex at 0x7fc03685fe20>,
#             <Reaction CYSDtex at 0x7fc03685f040>,
#             <Reaction CYStex at 0x7fc03688bbb0>,
#             <Reaction CYTDtex at 0x7fc036836f70>,
#             <Reaction DALAtex at 0x7fc03688c130>,
#             <Reaction DAMPtex at 0x7fc03688cbb0>,
#             <Reaction DAPtex at 0x7fc0368a29a0>,
#             <Reaction DARBtex at 0x7fc01ba7dcd0>,
#             <Reaction DCAtex at 0x7fc03685fbb0>,
#             <Reaction DCMPtex at 0x7fc0368cbdf0>,
#             <Reaction DDGLCNtex at 0x7fc036875e50>,
#             <Reaction DGMPtex at 0x7fc03688beb0>,
#             <Reaction DGSNtex at 0x7fc03688bfd0>,
#             <Reaction DHAtex at 0x7fc036836cd0>,
#             <Reaction DIMPtex at 0x7fc0367dc8e0>,
#             <Reaction DINStex at 0x7fc0367dce20>,
#             <Reaction DMSOtex at 0x7fc036806f40>,
#             <Reaction DMStex at 0x7fc03679f7c0>,
#             <Reaction DOPAtex at 0x7fc03679fd60>,
#             <Reaction DOXRBCNtex at 0x7fc03679fdf0>,
#             <Reaction DSERtex at 0x7fc0367c1e50>,
#             <Reaction DTMPtex at 0x7fc0367c1c70>,
#             <Reaction DUMPtex at 0x7fc03676beb0>,
#             <Reaction D_LACtex at 0x7fc036847ac0>,
#             <Reaction ETHAtex at 0x7fc03672dd90>,
#             <Reaction ETHSO3tex at 0x7fc036716f40>,
#             <Reaction ETOHtex at 0x7fc03672ddc0>,
#             <Reaction F6Ptex at 0x7fc036743b80>,
#             <Reaction FALDtex at 0x7fc0366e7a60>,
#             <Reaction FE2tex at 0x7fc0366a6d30>,
#             <Reaction FE3tex at 0x7fc036622fd0>,
#             <Reaction FORtex at 0x7fc036622d30>,
#             <Reaction FRULYStex at 0x7fc036639d30>,
#             <Reaction FRUURtex at 0x7fc03664beb0>,
#             <Reaction FRUtex at 0x7fc03664bd90>,
#             <Reaction FUCtex at 0x7fc03664bf70>,
#             <Reaction FUMtex at 0x7fc0365e29d0>,
#             <Reaction FUSAtex at 0x7fc0365f3d30>,
# ...
#  'OmpG': frozenset({<Reaction H2Otex at 0x7fc03448e430>}),
#  'Pgm': frozenset({<Reaction PGMT at 0x7fc033f309a0>}),
#  'OmpA': frozenset({<Reaction H2Otex at 0x7fc03448e430>}),
#  'MaeA': frozenset({<Reaction ME1 at 0x7fc034203fa0>}),
#  'PgpA': frozenset({<Reaction PGPP120 at 0x7fc033f60d30>,
#             <Reaction PGPP120pp at 0x7fc033f60d60>,
#             <Reaction PGPP140 at 0x7fc033f60f10>,
#             <Reaction PGPP140pp at 0x7fc033f49e80>,
#             <Reaction PGPP141 at 0x7fc033f49dc0>,
#             <Reaction PGPP141pp at 0x7fc033f30df0>,
#             <Reaction PGPP160 at 0x7fc033f60f70>,
#             <Reaction PGPP160pp at 0x7fc033f60820>,
#             <Reaction PGPP161 at 0x7fc033f49eb0>,
#             <Reaction PGPP161pp at 0x7fc033ef8d90>,
#             <Reaction PGPP180 at 0x7fc033ef8ee0>,
#             <Reaction PGPP180pp at 0x7fc033ef8fd0>,
#             <Reaction PGPP181 at 0x7fc033ef8e20>,
#             <Reaction PGPP181pp at 0x7fc033ef8be0>}),
#  'MaeB': frozenset({<Reaction ME2 at 0x7fc034217e20>}),
#  'PgsA': frozenset({<Reaction PGSA120 at 0x7fc033ef8d00>,
#             <Reaction PGSA140 at 0x7fc033ef8d60>,
#             <Reaction PGSA141 at 0x7fc033f0fd90>,
#             <Reaction PGSA160 at 0x7fc033f0feb0>,
#             <Reaction PGSA161 at 0x7fc033f0ffa0>,
#             <Reaction PGSA180 at 0x7fc033f0ff10>,
#             <Reaction PGSA181 at 0x7fc033f24d90>}),
#  'IspG': frozenset({<Reaction MECDPDH2 at 0x7fc01bbb3dc0>,
#             <Reaction MECDPDH5 at 0x7fc03420ec70>}),
#  'AqpZ': frozenset({<Reaction H2Otpp at 0x7fc0344a1ca0>}),
#  'CcmB': frozenset({<Reaction PHEMEabcpp at 0x7fc033f24d60>}),
#  'UbiA': frozenset({<Reaction HBZOPT at 0x7fc03445dcd0>}),
#  'CcmE': frozenset({<Reaction PHEMEabcpp at 0x7fc033f24d60>}),
#  'MhpT': frozenset({<Reaction HCINNMt2rpp at 0x7fc03445dfa0>,
#             <Reaction HPPPNt2rpp at 0x7fc0343ee700>}),
#  'CynT': frozenset({<Reaction HCO3E at 0x7fc0343f0c70>}),
#  'IspF': frozenset({<Reaction MECDPS at 0x7fc034217ee0>}),
#  'MelB': frozenset({<Reaction MELIBt2pp at 0x7fc03420e8b0>}),
#  'CcmC': frozenset({<Reaction PHEMEabcpp at 0x7fc033f24d60>}),
#  'IspD': frozenset({<Reaction MEPCT at 0x7fc03422cac0>}),
#  'Can': frozenset({<Reaction HCO3E at 0x7fc0343f0c70>}),
#  'CcmD': frozenset({<Reaction PHEMEabcpp at 0x7fc033f24d60>}),
#  'CyoE': frozenset({<Reaction HEMEOS at 0x7fc0343f0f10>}),
#  'MetK': frozenset({<Reaction METAT at 0x7fc034217f40>}),
#  'CcmA': frozenset({<Reaction PHEMEabcpp at 0x7fc033f24d60>}),
#  'MetN': frozenset({<Reaction METDabcpp at 0x7fc0341c46a0>,
#             <Reaction METabcpp at 0x7fc0341e4af0>}),
#  'PheS': frozenset({<Reaction PHETRS at 0x7fc033ebcaf0>}),
#  'MetI': frozenset({<Reaction METDabcpp at 0x7fc0341c46a0>,
#             <Reaction METabcpp at 0x7fc0341e4af0>}),
#  'RfaP': frozenset({<Reaction HEPK1 at 0x7fc034405bb0>,
#             <Reaction HEPKA1 at 0x7fc01bb2dee0>,
#             <Reaction HEPKB1 at 0x7fc01bad4700>}),
#  'PheT': frozenset({<Reaction PHETRS at 0x7fc033ebcaf0>}),
#  'PheP': frozenset({<Reaction PHEt2rpp at 0x7fc033ebcb50>,
#             <Reaction TYRt2rpp at 0x7fc033d269d0>}),
#  'RfaY': frozenset({<Reaction HEPK2 at 0x7fc034405d90>,
#             <Reaction HEPKA2 at 0x7fc01bac1ee0>,
#             <Reaction HEPKB2 at 0x7fc01bad4c40>}),
#  'RfaC': frozenset({<Reaction HEPT1 at 0x7fc034405df0>,
#             <Reaction HEPTA1 at 0x7fc01bb2dfd0>,
#             <Reaction HEPTB1 at 0x7fc01bb2df40>}),
#  'MetQ': frozenset({<Reaction METDabcpp at 0x7fc0341c46a0>,
#             <Reaction METabcpp at 0x7fc0341e4af0>}),
#  'MetE': frozenset({<Reaction METS at 0x7fc0341c4400>}),
#  'YddG': frozenset({<Reaction PHEt2rpp at 0x7fc033ebcb50>,
#             <Reaction TRPt2rpp at 0x7fc01bc4cfd0>,
#             <Reaction TYRt2rpp at 0x7fc033d269d0>}),
#  'RfaF': frozenset({<Reaction HEPT2 at 0x7fc034405e20>,
#             <Reaction HEPTA2 at 0x7fc01bb2d910>,
#             <Reaction HEPTB2 at 0x7fc01bac1bb0>}),
#  'PitA': frozenset({<Reaction PIt2rpp at 0x7fc033f24cd0>}),
#  'RfaQ': frozenset({<Reaction HEPT3 at 0x7fc034405eb0>,
#             <Reaction HEPTA3 at 0x7fc01bac1d60>,
#             <Reaction HEPTB3 at 0x7fc01bad4f10>}),
#  'MetH': frozenset({<Reaction METS at 0x7fc0341c4400>}),
#  'PitB': frozenset({<Reaction PIt2rpp at 0x7fc033f24cd0>}),
#  'MsrA': frozenset({<Reaction METSOXR1 at 0x7fc0341c4be0>}),
#  'MsrB': frozenset({<Reaction METSOXR2 at 0x7fc0341d8400>}),
#  'ThiM': frozenset({<Reaction HETZK at 0x7fc03441bfa0>}),
#  'PstA': frozenset({<Reaction PIuabcpp at 0x7fc033ed1be0>}),
#  'MetG': frozenset({<Reaction METTRS at 0x7fc0341e4cd0>}),
#  'PstB': frozenset({<Reaction PIuabcpp at 0x7fc033ed1be0>}),
#  'MgtA': frozenset({<Reaction MG2uabcpp at 0x7fc034177eb0>,
#             <Reaction NI2uabcpp at 0x7fc0340c08e0>}),
#  'MgsA': frozenset({<Reaction MGSA at 0x7fc03418dfa0>}),
#  'PstS': frozenset({<Reaction PIuabcpp at 0x7fc033ed1be0>}),
#  'MalZ': frozenset({<Reaction MLTG1 at 0x7fc034224d90>,
#             <Reaction MLTG2 at 0x7fc034217f10>,
#             <Reaction MLTG3 at 0x7fc03422ccd0>,
#             <Reaction MLTG4 at 0x7fc0341b8640>,
#             <Reaction MLTG5 at 0x7fc034224b50>}),
#  'PstC': frozenset({<Reaction PIuabcpp at 0x7fc033ed1be0>}),
#  'Glk': frozenset({<Reaction HEX1 at 0x7fc03441be20>}),
#  'PldA': frozenset({<Reaction PLIPA1A120pp at 0x7fc033f24fd0>,
#             <Reaction PLIPA1A140pp at 0x7fc033ebc910>,
#             <Reaction PLIPA1A141pp at 0x7fc033ee4a60>,
#             <Reaction PLIPA1A160pp at 0x7fc033ee49d0>,
#             <Reaction PLIPA1A161pp at 0x7fc033ee4970>,
#             <Reaction PLIPA1A180pp at 0x7fc033f9ae20>,
#             <Reaction PLIPA1A181pp at 0x7fc033f30bb0>,
#             <Reaction PLIPA1E120pp at 0x7fc033f60ee0>,
#             <Reaction PLIPA1E140pp at 0x7fc033ef8430>,
#             <Reaction PLIPA1E141pp at 0x7fc033f0fd00>,
#             <Reaction PLIPA1E160pp at 0x7fc033f0fbe0>,
#             <Reaction PLIPA1E161pp at 0x7fc033ed1e20>,
#             <Reaction PLIPA1E180pp at 0x7fc033ed1850>,
#             <Reaction PLIPA1E181pp at 0x7fc033ee4ee0>,
#             <Reaction PLIPA1G120pp at 0x7fc033e79370>,
#             <Reaction PLIPA1G140pp at 0x7fc033e79f70>,
#             <Reaction PLIPA1G141pp at 0x7fc033e8edc0>,
#             <Reaction PLIPA1G160pp at 0x7fc033ea3970>,
#             <Reaction PLIPA1G161pp at 0x7fc033e4f550>,
#             <Reaction PLIPA1G180pp at 0x7fc033e39fd0>,
#             <Reaction PLIPA1G181pp at 0x7fc033df6460>,
#             <Reaction PLIPA2A120pp at 0x7fc033e0bd60>,
#             <Reaction PLIPA2A140pp at 0x7fc033db4df0>,
#             <Reaction PLIPA2A141pp at 0x7fc033db4ac0>,
#             <Reaction PLIPA2A160pp at 0x7fc033db4c10>,
#             <Reaction PLIPA2A161pp at 0x7fc033db4d60>,
#             <Reaction PLIPA2A180pp at 0x7fc033defeb0>,
#             <Reaction PLIPA2A181pp at 0x7fc033d99d30>,
#             <Reaction PLIPA2E120pp at 0x7fc033d40f70>,
#             <Reaction PLIPA2E140pp at 0x7fc033d40790>,
#             <Reaction PLIPA2E141pp at 0x7fc033d40880>,
#             <Reaction PLIPA2E160pp at 0x7fc033cffd90>,
#             <Reaction PLIPA2E161pp at 0x7fc033cffe20>,
#             <Reaction PLIPA2E180pp at 0x7fc033d26b80>,
#             <Reaction PLIPA2E181pp at 0x7fc01bcb8f70>,
#             <Reaction PLIPA2G120pp at 0x7fc01bccfa60>,
#             <Reaction PLIPA2G140pp at 0x7fc01bc8c8e0>,
#             <Reaction PLIPA2G141pp at 0x7fc01bc9fc70>,
#             <Reaction PLIPA2G160pp at 0x7fc01bc9ff10>,
#             <Reaction PLIPA2G161pp at 0x7fc01bc4cd30>,
#             <Reaction PLIPA2G180pp at 0x7fc01bc61c40>,
#             <Reaction PLIPA2G181pp at 0x7fc01bbf4be0>}),
#  'MltC': frozenset({<Reaction MLTGY1pp at 0x7fc0341b88e0>,
#             <Reaction MLTGY2pp at 0x7fc03422cb50>,
#             <Reaction MLTGY3pp at 0x7fc0341cdee0>,
#             <Reaction MLTGY4pp at 0x7fc0341cdac0>}),
#  'CpsG': frozenset({<Reaction PMANM at 0x7fc01bc61e20>}),
#  'EmtA': frozenset({<Reaction MLTGY1pp at 0x7fc0341b88e0>,
#             <Reaction MLTGY2pp at 0x7fc03422cb50>,
#             <Reaction MLTGY3pp at 0x7fc0341cdee0>,
#             <Reaction MLTGY4pp at 0x7fc0341cdac0>}),
#  'Mak': frozenset({<Reaction HEX7 at 0x7fc03441b8b0>}),
#  'BioH': frozenset({<Reaction PMEACPE at 0x7fc01bbc9f40>}),
#  'HisD': frozenset({<Reaction HISTD at 0x7fc0343b1910>}),
#  'MltB': frozenset({<Reaction MLTGY1pp at 0x7fc0341b88e0>,
#             <Reaction MLTGY2pp at 0x7fc03422cb50>,
#             <Reaction MLTGY3pp at 0x7fc0341cdee0>,
#             <Reaction MLTGY4pp at 0x7fc0341cdac0>}),
#  'CoaA': frozenset({<Reaction PNTK at 0x7fc01bbc9cd0>}),
#  'Slt': frozenset({<Reaction MLTGY1pp at 0x7fc0341b88e0>,
#             <Reaction MLTGY2pp at 0x7fc03422cb50>,
#             <Reaction MLTGY3pp at 0x7fc0341cdee0>,
#             <Reaction MLTGY4pp at 0x7fc0341cdac0>}),
#  'MltA': frozenset({<Reaction MLTGY1pp at 0x7fc0341b88e0>,
#             <Reaction MLTGY2pp at 0x7fc03422cb50>,
#             <Reaction MLTGY3pp at 0x7fc0341cdee0>,
#             <Reaction MLTGY4pp at 0x7fc0341cdac0>}),
#  'PanF': frozenset({<Reaction PNTOt4pp at 0x7fc01bbdba90>}),
#  'ScpB': frozenset({<Reaction MMCD at 0x7fc0341b8cd0>}),
#  'HisB': frozenset({<Reaction HISTP at 0x7fc0343b1af0>,
#             <Reaction IGPDH at 0x7fc03441bf70>}),
#  'RutC': frozenset({<Reaction POAACR at 0x7fc01bb879a0>}),
#  'HisS': frozenset({<Reaction HISTRS at 0x7fc0343b1f40>}),
#  'ScpA': frozenset({<Reaction MMM2 at 0x7fc01bbdbf40>,
#             <Reaction MMM at 0x7fc0341e4a60>}),
#  'MtlA': frozenset({<Reaction MNLptspp at 0x7fc0341779d0>}),
#  'YdbK': frozenset({<Reaction POR5 at 0x7fc01bb87280>}),
#  'UxuA': frozenset({<Reaction MNNH at 0x7fc0341e4dc0>}),
#  'PoxB': frozenset({<Reaction POX at 0x7fc01bb9fe50>}),
#  'HisJ': frozenset({<Reaction HISabcpp at 0x7fc0343b1ca0>}),
#  'Ppx': frozenset({<Reaction PPA2 at 0x7fc01bb9feb0>,
#             <Reaction PPA at 0x7fc01bb9fa00>}),
#  'AroP': frozenset({<Reaction HISt2rpp at 0x7fc0343b1f10>,
#             <Reaction PHEt2rpp at 0x7fc033ebcb50>,
#             <Reaction TRPt2rpp at 0x7fc01bc4cfd0>,
#             <Reaction TYRt2rpp at 0x7fc033d269d0>}),
#  'MoaD': frozenset({<Reaction MOADSUx at 0x7fc034177b80>,
#             <Reaction MPTS at 0x7fc0341a0e50>}),
#  'Ppa': frozenset({<Reaction PPA at 0x7fc01bb9fa00>}),
#  'WaaA': frozenset({<Reaction MOAT2 at 0x7fc034177c10>,
#             <Reaction MOAT at 0x7fc0341e4df0>}),
#  'MhpC': frozenset({<Reaction HKNDDH at 0x7fc0343daee0>,
#             <Reaction HKNTDH at 0x7fc0343daeb0>}),
#  'HemC': frozenset({<Reaction HMBS at 0x7fc0343c5fd0>}),
#  'ThiD': frozenset({<Reaction HMPK1 at 0x7fc0343daa90>,
#             <Reaction PMPK at 0x7fc01bc1ecd0>}),
#  'PutP': frozenset({<Reaction PPAt4pp at 0x7fc01bb34be0>,
#             <Reaction PROt4pp at 0x7fc033f24ca0>}),
#  'PdxK': frozenset({<Reaction HMPK1 at 0x7fc0343daa90>,
#             <Reaction PYDAMK at 0x7fc033e60970>,
#             <Reaction PYDXK at 0x7fc033e60df0>,
#             <Reaction PYDXNK at 0x7fc033df6cd0>}),
#  'RhtA': frozenset({<Reaction HOMt2pp at 0x7fc0343eed60>,
#             <Reaction THRt2pp at 0x7fc033d26e50>}),
#  'YbhA': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction PDXPP at 0x7fc033f49d00>,
#             <Reaction PYDXPP at 0x7fc033e0beb0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TUNGSabcpp at 0x7fc01bc61af0>}),
#  'CysU': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SELtpp at 0x7fc033d84eb0>,
#             <Reaction SLNTtpp at 0x7fc033d56dc0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TSULabcpp at 0x7fc01bc4cdf0>}),
#  'CysA': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SELtpp at 0x7fc033d84eb0>,
#             <Reaction SLNTtpp at 0x7fc033d56dc0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TSULabcpp at 0x7fc01bc4cdf0>}),
#  'HemB': frozenset({<Reaction PPBNGS at 0x7fc01bb34f40>}),
#  'CysP': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SELtpp at 0x7fc033d84eb0>,
#             <Reaction SLNTtpp at 0x7fc033d56dc0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TSULabcpp at 0x7fc01bc4cdf0>}),
#  'RhtB': frozenset({<Reaction HOMt2pp at 0x7fc0343eed60>}),
#  'Ppc': frozenset({<Reaction PPC at 0x7fc01bb34820>}),
#  'MhpE': frozenset({<Reaction HOPNTAL at 0x7fc0343eef70>}),
#  'Dfp': frozenset({<Reaction PPCDC at 0x7fc01bb48550>,
#             <Reaction PPNCL2 at 0x7fc01bb5c8e0>}),
#  'Pck': frozenset({<Reaction PPCK at 0x7fc01bb483d0>}),
#  'FolK': frozenset({<Reaction HPPK2 at 0x7fc0343eef10>}),
#  'Sbp': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TSULabcpp at 0x7fc01bc4cdf0>}),
#  'ScpC': frozenset({<Reaction PPCSCT at 0x7fc01bb48f40>}),
#  'CysW': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SELtpp at 0x7fc033d84eb0>,
#             <Reaction SLNTtpp at 0x7fc033d56dc0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TSULabcpp at 0x7fc01bc4cdf0>}),
#  'ModC': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TUNGSabcpp at 0x7fc01bc61af0>}),
#  'ModA': frozenset({<Reaction MOBDabcpp at 0x7fc034177bb0>,
#             <Reaction SULabcpp at 0x7fc033d99eb0>,
#             <Reaction TUNGSabcpp at 0x7fc01bc61af0>}),
#  'MocA': frozenset({<Reaction MOCDS at 0x7fc03418df40>}),
#  'Hyi': frozenset({<Reaction HPYRI at 0x7fc034385fd0>}),
#  'ThrB': frozenset({<Reaction HSK at 0x7fc0343dafa0>}),
#  'MetA': frozenset({<Reaction HSST at 0x7fc036da0cd0>}),
#  'HisC': frozenset({<Reaction HSTPT at 0x7fc036da0c10>}),
#  'Ppk': frozenset({<Reaction PPK2 at 0x7fc01bb485b0>,
#             <Reaction PPK at 0x7fc01bb487c0>}),
#  'XdhA': frozenset({<Reaction HXAND at 0x7fc03ffec280>,
#             <Reaction XAND at 0x7fc01bc9f430>}),
#  'DeoB': frozenset({<Reaction PPM2 at 0x7fc01bb5c910>,
#             <Reaction PPM at 0x7fc01bb5ceb0>}),
#  'XdhB': frozenset({<Reaction HXAND at 0x7fc03ffec280>,
#             <Reaction XAND at 0x7fc01bc9f430>}),
#  'PanB': frozenset({<Reaction MOHMT at 0x7fc0341a0df0>}),
#  'Mog': frozenset({<Reaction MPTAT at 0x7fc03418dc40>}),
#  'PbpC': frozenset({<Reaction MPTG2 at 0x7fc0341a0fd0>,
#             <Reaction MPTG at 0x7fc0341e4f10>}),
#  'YhfW': frozenset({<Reaction PPM at 0x7fc01bb5ceb0>}),
#  'MurJ': frozenset({<Reaction LIPIDIIFLIP at 0x7fc01baa5dc0>,
#             <Reaction MPTG2 at 0x7fc0341a0fd0>,
#             <Reaction MPTG at 0x7fc0341e4f10>}),
#  'HemG': frozenset({<Reaction PPPGO3 at 0x7fc01baf1640>,
#             <Reaction PPPGO at 0x7fc01baf1cd0>}),
#  'MoaE': frozenset({<Reaction MPTS at 0x7fc0341a0e50>}),
#  'XdhC': frozenset({<Reaction HXAND at 0x7fc03ffec280>,
#             <Reaction XAND at 0x7fc01bc9f430>}),
#  'HcaT': frozenset({<Reaction PPPNt2rpp at 0x7fc01baf1df0>}),
#  'HyaC': frozenset({<Reaction HYD1pp at 0x7fc034435d90>,
#             <Reaction HYD2pp at 0x7fc034435e80>,
#             <Reaction HYD3pp at 0x7fc034435c10>}),
#  'PpsA': frozenset({<Reaction PPS at 0x7fc01bb19d00>}),
#  'HybO': frozenset({<Reaction HYD1pp at 0x7fc034435d90>,
#             <Reaction HYD2pp at 0x7fc034435e80>,
#             <Reaction HYD3pp at 0x7fc034435c10>}),
#  'HyaB': frozenset({<Reaction HYD1pp at 0x7fc034435d90>,
#             <Reaction HYD2pp at 0x7fc034435e80>,
#             <Reaction HYD3pp at 0x7fc034435c10>}),
#  'MoeB': frozenset({<Reaction MPTSS at 0x7fc0341a0cd0>}),
#  'PhoA': frozenset({<Reaction PPTHpp at 0x7fc01bb19160>}),
#  'HyaA': frozenset({<Reaction HYD1pp at 0x7fc034435d90>,
#             <Reaction HYD2pp at 0x7fc034435e80>,
#             <Reaction HYD3pp at 0x7fc034435c10>}),
#  'PurD': frozenset({<Reaction PRAGSr at 0x7fc033ef8c40>}),
#  'RutE': frozenset({<Reaction MSAR at 0x7fc034133e80>}),
#  'PurM': frozenset({<Reaction PRAIS at 0x7fc033fec970>}),
#  'FolD': frozenset({<Reaction MTHFC at 0x7fc03414b8e0>,
#             <Reaction MTHFD at 0x7fc03414bcd0>}),
#  'HybA': frozenset({<Reaction HYD1pp at 0x7fc034435d90>,
#             <Reaction HYD2pp at 0x7fc034435e80>,
#             <Reaction HYD3pp at 0x7fc034435c10>}),
#  'HisI': frozenset({<Reaction PRAMPC at 0x7fc033ef8e80>,
#             <Reaction PRATPP at 0x7fc033f0fdf0>}),
#  ...}

# %%
one= pd.read_csv("one feasible value reactions M9 media.csv")
flat= pd.read_csv("flat M9 media.csv")
diff_saturated= pd.read_csv("diff_saturated M9 media.csv")
Ushaped= pd.read_csv("Ushaped_reactions M9 media.csv")
monotonically_increasingANDstable_reactions= pd.read_csv("monotonically increasing and stable reactions M9 media.csv")
monotonically_increasing_only_reactions= pd.read_csv("monotonically increasing only reactions M9 media.csv")
monotonically_decreasingANDstable_reactions= pd.read_csv("monotonically decreasing and stable reactions M9 media.csv")
monotonically_decreasing_only_reactions= pd.read_csv("monotonically decreasing only reactions M9 media.csv")
increasingANDdecreasingANDstable_reactions= pd.read_csv("increasing and decreasing and stable reactions M9 media.csv")
increasingANDdecreasing_only_reactions= pd.read_csv("increasing and decreasing only reactions M9 media.csv")

# %%
import csv

with open('dictionary.csv', 'w') as f:  
    writer = csv.writer(f)
    for k, v in dictionary.items():
       writer.writerow([k, v])

# %%
import pandas as pd
p= pd.read_csv('dictionary.csv', header= None)
p

headerList= ["Gene name", "Reaction"]
p.to_csv("dictionary_NEW.csv", header=headerList, index=False)
p2 = pd.read_csv("dictionary_NEW.csv")
print('\nModified file:')
print(p2)
# Out:
# Modified file:
#        Gene name                                           Reaction
# 0           PhoE  frozenset({<Reaction DALAtex at 0x7fc03688c130...
# 1           YlbA  frozenset({<Reaction UGCIAMH at 0x7fc01b9faca0>})
# 2           OmpC  frozenset({<Reaction DALAtex at 0x7fc03688c130...
# 3           OmpF  frozenset({<Reaction DALAtex at 0x7fc03688c130...
# 4           OmpN  frozenset({<Reaction DALAtex at 0x7fc03688c130...
# ...          ...                                                ...
# 1339        YcjT      frozenset({<Reaction MPL at 0x7fc01ba4be80>})
# 1340        YafJ     frozenset({<Reaction ASNO at 0x7fc01ba4bfd0>})
# 1341        YgdH    frozenset({<Reaction PYRDC at 0x7fc01ba61d90>})
# 1342  Locus 3025  frozenset({<Reaction HPA3MOFAD at 0x7fc01ba61b...
# 1343        YcjM     frozenset({<Reaction SUCP at 0x7fc01ba61c70>})
#
# [1344 rows x 2 columns]

# %%
boolean_findings = p2['Reaction'].str.contains('UGCIAMH')

boolean_findings

i=0
gene_names= list()
while i <1343:
    if boolean_findings[i] ==True:
        
        l= p2.iloc[i, 0]
        gene_names.append(l)
    i=i+1
gene_names
# Out:
# ['YlbA']

# %%
diff_saturated["Reaction names"]
# Out:
# 0          EX_ppt_e
# 1          EX_fe2_e
# 2     ACOLIPAabctex
# 3               ADA
# 4               ADD
#           ...
# 87              POX
# 88              PPK
# 89              PPM
# 90    L_LACD2_copy2
# 91      XTSNH_copy2
# Name: Reaction names, Length: 92, dtype: object

# %%
z=0
saturated_gene_names= list()
l= str()

while z< len(diff_saturated):

    boolean_findings = p2['Reaction'].str.contains(diff_saturated["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            saturated_gene_names.append(l)
        i=i+1
    
    z=z+1

saturated_gene_names
# Out:
# ['LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'DdpX',
#  'GlyA',
#  'LtaE',
#  'PuuC',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'CarA',
#  'CarB',
#  'ZntA',
#  'ZntA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ProP',
#  'CopA',
#  'CydD',
#  'CydC',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ArtM',
#  'ArtJ',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ArtP',
#  'ArtI',
#  'ArtQ',
#  'FeoB',
#  'GlpA',
#  'GlpD',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'NadB',
#  'NadB',
#  'NadB',
#  'MglC',
#  'MglA',
#  'MglB',
#  'AspA',
#  'AspC',
#  'AspS',
#  'YtfR',
#  'YtfT',
#  'MglC',
#  'MglA',
#  'YjfF',
#  'YtfQ',
#  'MglB',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'IdnD',
#  'ZntA',
#  'GhrB',
#  'GhrA',
#  'Dld',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'Mqo',
#  'Mqo',
#  'MgtA',
#  'Ndh',
#  'Ndh',
#  'Ndh',
#  'MdaB',
#  'MdaB',
#  'MdaB',
#  'PntA',
#  'PntB',
#  'SthA',
#  'ZntA',
#  'HscC',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'AppA',
#  'RsgA',
#  'MutT',
#  'MazG',
#  'RdgB',
#  'MutT',
#  'MazG',
#  'NudI',
#  'MazG',
#  'NudG',
#  'MazG',
#  'NudG',
#  'NudB',
#  'MazG',
#  'MazG',
#  'NudI',
#  'MazG',
#  'MazG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'Lpd',
#  'FldB',
#  'FldA',
#  'Zwf',
#  'AceF',
#  'AceE',
#  'IspG',
#  'HisB',
#  'PotD',
#  'PotB',
#  'PotF',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotI',
#  'PotH',
#  'PotG',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'GlyA',
#  'LtaE',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'XylH',
#  'XylG',
#  'XylF',
#  'ZntA',
#  'PoxB',
#  'SolA',
#  'Ppx',
#  'SurE',
#  'HemF',
#  'HemN',
#  'HemG',
#  'PreB',
#  'PreA',
#  'YgdH']

# %%
z=0
one_gene_names= list()
l= str()

while z< len(one):

    boolean_findings = p2['Reaction'].str.contains(one['1 feasible value'][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            one_gene_names.append(l)
        i=i+1
    
    z=z+1

one_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'RutD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'MhpA',
#  'RffT',
#  'MalS',
#  'MhpA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LyxK',
#  'BglA',
#  'Prr',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabG',
#  'FabG',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'NhoA',
#  'CobU',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabF',
#  'FabB',
#  'FabF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NagK',
#  'Rfe',
#  'FabB',
#  'FabF',
#  'OppF',
#  'MppA',
#  'OppB',
#  'OppC',
#  'OppD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TynA',
#  'PtsH',
#  'NagE',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThrC',
#  'LdcA',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'OppF',
#  'OppB',
#  'OppC',
#  'OppD',
#  'OppA',
#  'MurQ',
#  'RffM',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'MurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NanT',
#  'Mtn',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GutQ',
#  'KdsD',
#  'OmpC',
#  'OmpF',
#  'Deleted',
#  'NanA',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'ArgE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'S0001',
#  'Tam',
#  'AstC',
#  'ArgD',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Mtn',
#  'Aas',
#  'AcpP',
#  'AcpT',
#  'AcpS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PabC',
#  'PabA',
#  'PabB',
#  'YcjG',
#  'AlaS',
#  'XanP',
#  'PurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SpeD',
#  'FrmA',
#  'AdhE',
#  'FrmA',
#  'AdhP',
#  'AldB',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'CobU',
#  'CobS',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'AlsK',
#  'RpiB',
#  'AllC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AllB',
#  'YbbW',
#  'AlsE',
#  'CysC',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'TrpD',
#  'TrpE',
#  'GlpE',
#  'PspE',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'NagZ',
#  'AmpG',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'LdcA',
#  'DkgB',
#  'DkgA',
#  'Gpr',
#  'YeaE',
#  'GldA',
#  'UxaA',
#  'AmpD',
#  'AmpD',
#  'LdcA',
#  'MalQ',
#  'NanE',
#  'NanK',
#  'NagZ',
#  'AmpG',
#  'NagZ',
#  'RfaD',
#  'RfaD',
#  'SpeB',
#  'AmpG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioA',
#  'UbiE',
#  'ThiC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'BioF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnmK',
#  'TrpD',
#  'ApaH',
#  'AspS',
#  'SpeE',
#  'ArsC',
#  'GrxB',
#  'QueF',
#  'AstA',
#  'IspE',
#  'Cfa',
#  'Cfa',
#  'Cfa',
#  'HisG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Cfa',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MoeA',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'CysQ',
#  'BetA',
#  'PheA',
#  'TyrA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioB',
#  'AroC',
#  'MenF',
#  'EntC',
#  'UbiC',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoA',
#  'AtoD',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'HcaF',
#  'HcaD',
#  'HcaE',
#  'HcaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'MoeA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CadB',
#  'YbhO',
#  'Cls',
#  'BtuR',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'BtuR',
#  'S0001',
#  'ClcB',
#  'ClcA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'QueC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GldA',
#  'LpxT',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'MsbA',
#  'RibD',
#  'MoaC',
#  'MoaA',
#  'HemF',
#  'HemN',
#  'HemN',
#  'CaiB',
#  'CaiD',
#  'CaiB',
#  'AraA',
#  'CaiD',
#  'CaiC',
#  'QueD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CaiT',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YgeX',
#  'LysA',
#  'DapF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RibB',
#  'BioD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpE',
#  'PspE',
#  'PspE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CynS',
#  'CynX',
#  'ChbF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'FadL',
#  'DgoK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CsdA',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MetC',
#  'MalY',
#  'CysS',
#  'AroG',
#  'AroF',
#  'AroH',
#  'DgoA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IlvD',
#  'IlvD',
#  'PtsH',
#  'PtsI',
#  'AscF',
#  'BglF',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'EntA',
#  'HcaB',
#  'MhpB',
#  'MhpB',
#  'DapB',
#  'AroD',
#  'DapA',
#  'FolA',
#  'FolM',
#  'FolC',
#  'FolM',
#  'MenA',
#  'MenB',
#  'YbgC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DkgB',
#  'DkgA',
#  'FolB',
#  'PyrC',
#  'IspA',
#  'RibD',
#  'HcaB',
#  'UbiG',
#  'RibD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FolP',
#  'S0001',
#  'NfsB',
#  'AdiC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NudB',
#  'MutT',
#  'NfsB',
#  'FolX',
#  'AroB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CoaE',
#  'NudF',
#  'NudE',
#  'IlvC',
#  'PanE',
#  'DapB',
#  'NadC',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzxE',
#  'DsbC',
#  'TrxA',
#  'TrxC',
#  'DsbD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FumB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'ArgH',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArgG',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'LpxL',
#  'LpxM',
#  'LpxP',
#  'LpxM',
#  'FabI',
#  'ArgS',
#  'Dxr',
#  'Dxs',
#  'XylB',
#  'Epd',
#  'GapA',
#  'EntD',
#  'FabI',
#  'EutB',
#  'EutC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TesB',
#  'UlaG',
#  'FadK',
#  'FadD',
#  'PtsH',
#  'PtsI',
#  'UlaC',
#  'UlaB',
#  'UlaA',
#  'FrmA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TesB',
#  'S0001',
#  'FadK',
#  'FadD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FucI',
#  'FucK',
#  'FucA',
#  'YgbL',
#  'HemH',
#  'SsuD',
#  'FadK',
#  'FadD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'CueO',
#  'Fmt',
#  'FecB',
#  'FecD',
#  'FecC',
#  'FecE',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FecA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'CirA',
#  'Fiu',
#  'RibF',
#  'AsnS',
#  'Frc',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FruK',
#  'FrlB',
#  'FrlC',
#  'FrlD',
#  'FrlA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GntP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'FruB',
#  'FruA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuF',
#  'ArsB',
#  'FhuF',
#  'Agp',
#  'RffH',
#  'RfbA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HemL',
#  'SuhB',
#  'AphA',
#  'YihU',
#  'PanD',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PyrI',
#  'PyrB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Maa',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Agp',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarL',
#  'GudX',
#  'GudD',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarD',
#  'YjjN',
#  'DgoD',
#  'YjjL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RfaG',
#  'RfaI',
#  'DgoT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GalK',
#  'WcaK',
#  'GalM',
#  'MelA',
#  'PtsH',
#  'PtsI',
#  'GatC',
#  'GatA',
#  'GatB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  ...]

# %%
z=0
flat_gene_names= list()
l= str()

while z< len(flat):

    boolean_findings = p2['Reaction'].str.contains(flat["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            flat_gene_names.append(l)
        i=i+1
    
    z=z+1

flat_gene_names
# Out:
# ['GhrB',
#  'GhrB',
#  'GhrB',
#  'GabP',
#  'FadA',
#  'AtoB',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Acs',
#  'Deleted',
#  'PurT',
#  'AckA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'Add',
#  'LpxC',
#  'RffT',
#  'Ade',
#  'LigA',
#  'NudC',
#  'GlyA',
#  'LtaE',
#  'AlaA',
#  'AlaC',
#  'CycA',
#  'YaaJ',
#  'Adk',
#  'Adk',
#  'FeaB',
#  'Adk',
#  'RihC',
#  'Apt',
#  'MalQ',
#  'MalQ',
#  'MalQ',
#  'Amn',
#  'GltP',
#  'BetB',
#  'BisC',
#  'ChaA',
#  'YrbG',
#  'CaiC',
#  'ProP',
#  'CaiT',
#  'Add',
#  'CaiC',
#  'FadB',
#  'FadB',
#  'FadB',
#  'CueO',
#  'PtsH',
#  'PtsI',
#  'DhaK',
#  'DhaL',
#  'DhaM',
#  'DadA',
#  'FolB',
#  'PyrD',
#  'GhrB',
#  'GhrB',
#  'IspH',
#  'FabI',
#  'FabI',
#  'FabI',
#  'DsbB',
#  'DsbA',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'YbiV',
#  'FabI',
#  'FabI',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'FabI',
#  'CysI',
#  'CysJ',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'AnsB',
#  'AsnB',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'Fau',
#  'GlgB',
#  'YbiV',
#  'GlgP',
#  'MalP',
#  'GlgP',
#  'MalP',
#  'GlgA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'GlgX',
#  'GlgC',
#  'GadC',
#  'PabB',
#  'AnsB',
#  'YbaS',
#  'YneH',
#  'GltP',
#  'GltS',
#  'GlxK',
#  'GarK',
#  'GarK',
#  'GhrB',
#  'GhrA',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'FadJ',
#  'FadB',
#  'Gpt',
#  'Hpt',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HycD',
#  'HycF',
#  'HycB',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'MenF',
#  'EntC',
#  'TolC',
#  'AcrF',
#  'AcrE',
#  'Mtr',
#  'RihC',
#  'Gsk',
#  'IspH',
#  'Hyi',
#  'GhrB',
#  'GhrA',
#  'FabB',
#  'FabF',
#  'FabH',
#  'CycA',
#  'YeaV',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'YaaJ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'MaeA',
#  'FldB',
#  'FldA',
#  'IspG',
#  'MalZ',
#  'MalZ',
#  'MalZ',
#  'ScpA',
#  'YbiV',
#  'AcnB',
#  'Gsk',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'ChaA',
#  'MdfA',
#  'Adk',
#  'Ndk',
#  'Hmp',
#  'NorV',
#  'NorW',
#  'BtuE',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'LplA',
#  'Dgt',
#  'Dgt',
#  'NirB',
#  'NirD',
#  'Gpp',
#  'Eda',
#  'Gpt',
#  'Hpt',
#  'PdxH',
#  'ProP',
#  'PutP',
#  'YgiN',
#  'PhnN',
#  'YbiV',
#  'AphA',
#  'Pta',
#  'EutD',
#  'Sad',
#  'SucD',
#  'SucC',
#  'DsdA',
#  'TnaA',
#  'SdaA',
#  'TdcG',
#  'SdaB',
#  'Deleted',
#  'SdaC',
#  'SstT',
#  'GlyA',
#  'GlyA',
#  'LtaE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Deleted',
#  'YdfG',
#  'CydD',
#  'CydC',
#  'Ggt',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'Tdh',
#  'IlvA',
#  'TrpA',
#  'TrpB',
#  'TrpA',
#  'TrpB',
#  'GlxR',
#  'GarR',
#  'Upp',
#  'UraA',
#  'RutG',
#  'AvtA',
#  'RihC',
#  'RihA',
#  'RihB',
#  'Udk',
#  'IlvE',
#  'RihC',
#  'LldD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcnB',
#  'ScpA',
#  'MenB',
#  'FadB',
#  'FadB',
#  'AvtA',
#  'ScpC',
#  'FolK',
#  'Ppk',
#  'DeoB',
#  'YhfW',
#  'LeuC',
#  'LeuD',
#  'GhrB',
#  'FeaB',
#  'FolB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'AraE',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'YdeA',
#  'FadJ',
#  'FadB',
#  'FadB',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'LldD',
#  'YiaK',
#  'RihC',
#  'RihA',
#  'RihB']

# %%
z=0
Ushaped_gene_names= list()
l= str()

while z< len(Ushaped):

    boolean_findings = p2['Reaction'].str.contains(Ushaped["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            Ushaped_gene_names.append(l)
        i=i+1
    
    z=z+1

Ushaped_gene_names
# Out:
# ['GlyA',
#  'LtaE',
#  'KatE',
#  'KatG',
#  'Maa',
#  'IaaA',
#  'AnsA',
#  'AnsB',
#  'PurT',
#  'GltD',
#  'GltB',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'MgtA',
#  'NikC',
#  'NikE',
#  'NikD',
#  'NikB',
#  'NikA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'PfkA',
#  'PfkB',
#  'PfkA',
#  'Prs',
#  'SodA',
#  'SodB',
#  'SodC',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'ZnuC',
#  'ZnuA',
#  'ZnuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'PlsX',
#  'NudB',
#  'MutT',
#  'Cdh',
#  'GmhB',
#  'Ppx',
#  'Ppa',
#  'PutP',
#  'SurE']

# %%
z=0
monotonically_increasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasingANDstable_reactions_gene_names
# Out:
# ['PyrD',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DsbB',
#  'DsbA',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'YgiN',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA']

# %%
z=0
monotonically_increasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasing_only_reactions_gene_names
# Out:
# ['GhrB',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'IdnO',
#  'IdnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'FabH',
#  'PurH',
#  'PurK',
#  'KgtP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Adk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YbbW',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PurB',
#  'Lpp',
#  'Lnt',
#  'Lpp',
#  'Lnt',
#  'PlsC',
#  'PlsC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PlsY',
#  'YdfG',
#  'PlsY',
#  'CycA',
#  'BetT',
#  'YeaV',
#  'BetB',
#  'BisC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YahI',
#  'YbcF',
#  'YqeA',
#  'CodB',
#  'ProP',
#  'PyrG',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'CysM',
#  'CysK',
#  'CsdA',
#  'SelA',
#  'KdgK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlcA',
#  'LldP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YiaK',
#  'AdiA',
#  'SpeA',
#  'FabI',
#  'FabI',
#  'YdfG',
#  'CycA',
#  'Eno',
#  'FabI',
#  'FabI',
#  'Fes',
#  'Fes',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'S0001',
#  'Fre',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'AnsP',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'FhuF',
#  'GlmU',
#  'AphA',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'ThrA',
#  'LysC',
#  'MetL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NadB',
#  'PtsH',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'MalX',
#  'GalP',
#  'GlnQ',
#  'GlnP',
#  'GlnH',
#  'GalP',
#  'AnsB',
#  'PurF',
#  'Gmm',
#  'YeaV',
#  'ProP',
#  'GlpT',
#  'Icd',
#  'IdnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'FieF',
#  'BrnQ',
#  'AroP',
#  'ThrB',
#  'GlcA',
#  'LldP',
#  'LacZ',
#  'BglX',
#  'GldA',
#  'PldB',
#  'PldB',
#  'PldB',
#  'BrnQ',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'LipB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Hmp',
#  'PnuC',
#  'UbiF',
#  'UbiH',
#  'UbiB',
#  'DctA',
#  'ProC',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'Pgi',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'GrxB',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'MsbA',
#  'MsbA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PurD',
#  'PgpB',
#  'PgpA',
#  'PurM',
#  'PgpB',
#  'PgpA',
#  'PurC',
#  'PurL',
#  'AphA',
#  'AraB',
#  'PotE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'DcuB',
#  'CysE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YeiG',
#  'FrmB',
#  'CysU',
#  'CysA',
#  'CysP',
#  'CysW',
#  'YchM',
#  'ThrC',
#  'GlmU',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'TreB',
#  'TrpA',
#  'TrpB',
#  'Mpl',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BrnQ',
#  'YgaH',
#  'YgaZ',
#  'IspG',
#  'XylE',
#  'FldB',
#  'FldA',
#  'YdbK',
#  'PutP',
#  'HemG',
#  'GhrB',
#  'DmlA']

# %%
z=0
monotonically_decreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasingANDstable_reactions_gene_names
# Out:
# ['DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'AldB',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'AppC',
#  'AppB',
#  'AppC',
#  'AppB',
#  'CydB',
#  'CydA',
#  'AraG',
#  'AraF',
#  'AraH',
#  'YdeA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'SpeA',
#  'MntH',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'XanP',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'HisJ',
#  'YdeA',
#  'SetB',
#  'SetA',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivK',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'CorA',
#  'NhaB',
#  'NhaA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'NapA',
#  'NapC',
#  'NapB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ProX',
#  'ProV',
#  'ProW',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'DcuA',
#  'DcuB',
#  'TrxA',
#  'TrxC',
#  'BtuE',
#  'Bcp',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'XanP',
#  'XanQ',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'AraG',
#  'AraF',
#  'AraH']

# %%
z=0
monotonically_decreasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasing_only_reactions_gene_names
# Out:
# ['LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'NudJ',
#  'Cof',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'GabT',
#  'PuuE',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'PlsC',
#  'AcpP',
#  'PlsX',
#  'PurE',
#  'AcpP',
#  'PlsX',
#  'EamA',
#  'EamB',
#  'CyaA',
#  'NudF',
#  'NudE',
#  'NagA',
#  'PlsC',
#  'PlsC',
#  'S0001',
#  'PlsC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PlsC',
#  'ApaH',
#  'LysU',
#  'PlsY',
#  'PlsY',
#  'PlsY',
#  'S0001',
#  'PlsY',
#  'DppF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PlsY',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ZupT',
#  'S0001',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuE',
#  'CodA',
#  'CdsA',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'CdsA',
#  'CdsA',
#  'ZntA',
#  'S0001',
#  'CdsA',
#  'CdsA',
#  'S0001',
#  'Cdd',
#  'MetC',
#  'TnaA',
#  'IscS',
#  'SufS',
#  'SufE',
#  'EntE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DeoC',
#  'YdgI',
#  'Eda',
#  'RhmA',
#  'Edd',
#  'PreB',
#  'PreA',
#  'DeoD',
#  'DeoA',
#  'NudI',
#  'Dut',
#  'ArgO',
#  'AcpH',
#  'Asd',
#  'AcpH',
#  'TesB',
#  'TesB',
#  'TesB',
#  'TesB',
#  'TesB',
#  'TesB',
#  'TesB',
#  'TesB',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FbaA',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'S0001',
#  'FieF',
#  'YtfE',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HyfI',
#  'HycD',
#  'HycF',
#  'HyfE',
#  'HycB',
#  'HyfC',
#  'HyfJ',
#  'FdhF',
#  'HyfF',
#  'HyfG',
#  'HyfA',
#  'HyfB',
#  'HyfH',
#  'HyfD',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FocB',
#  'FocA',
#  'Fre',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'S0001',
#  'TolC',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FepA',
#  'EntS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'GlyA',
#  'ProA',
#  'NagB',
#  'Zwf',
#  'Gcd',
#  'YliI',
#  'IdnT',
#  'KdgT',
#  'GntP',
#  'GntT',
#  'GntU',
#  'ProB',
#  'GshA',
#  'NudK',
#  'Gcl',
#  'AtoA',
#  'AtoD',
#  'AceA',
#  'Glk',
#  'Mak',
#  'PurH',
#  'GloB',
#  'ThrA',
#  'MetL',
#  'ChaA',
#  'KefC',
#  'KefB',
#  'MdfA',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'AldA',
#  'LacY',
#  'S0001',
#  'GloA',
#  'YdfG',
#  'ArgO',
#  'PrpD',
#  'PrpB',
#  'PrpC',
#  'CpsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MelB',
#  'YdeA',
#  'S0001',
#  'S0001',
#  'ScpB',
#  'TrxA',
#  'TrxC',
#  'BisC',
#  'MsrA',
#  'TrxA',
#  'TrxC',
#  'MsrB',
#  'ZitB',
#  'FieF',
#  'LigA',
#  'NudC',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'FolD',
#  'FolD',
#  'PncB',
#  'Gss',
#  'Gss',
#  'Adk',
#  'Ndk',
#  'S0001',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Gor',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'Ggt',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'PncA',
#  'CydD',
#  'CydC',
#  'RdgB',
#  'RdgB',
#  'GshB',
#  'RdgB',
#  'RelA',
#  'S0001',
#  'PutA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'GlmM',
#  'SerA',
#  'PldA',
#  'DosP',
#  'CpdB',
#  'DosP',
#  'YtjC',
#  'GpmA',
#  'GpmM',
#  'YqaB',
#  'Pgm',
#  'YbhA',
#  'MsbA',
#  'PldA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PutA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'SerC',
#  'AphA',
#  'SerB',
#  'PldA',
#  'PldA',
#  'PldA',
#  'RbsK',
#  'AraB',
#  'S0001',
#  'PldA',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PdxH',
#  'PdxK',
#  'PdxK',
#  'PdxY',
#  'PdxK',
#  'PldA',
#  'Cof',
#  'YbhA',
#  'YigL',
#  'RpiB',
#  'RpiA',
#  'PotD',
#  'PotB',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'MdtJ',
#  'MdtI',
#  'EntF',
#  'NudJ',
#  'IspB',
#  'RffC',
#  'RffA',
#  'RfbC',
#  'RfbD',
#  'RfbB',
#  'RffG',
#  'RhtA',
#  'RhtC',
#  'TktB',
#  'TktA',
#  'TktB',
#  'TktA',
#  'Tdk',
#  'TrxA',
#  'TrxC',
#  'TrxB',
#  'TnaA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SpoT',
#  'DeoB',
#  'FldB',
#  'FldA',
#  'Fpr']

# %%
z=0
increasingANDdecreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasingANDstable_reactions_gene_names
# Out:
# ['NapG',
#  'NapA',
#  'NapC',
#  'NapB',
#  'NapH',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'PykA',
#  'PykF',
#  'CyoC',
#  'CyoB',
#  'CyoD',
#  'CyoA',
#  'PstA',
#  'PstB',
#  'PstS',
#  'PstC',
#  'MntH',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'SdhD',
#  'SdhA',
#  'SdhB',
#  'SdhC',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'Deleted',
#  'KdpB',
#  'KdpC',
#  'KdpA',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH']

# %%
z=0
increasingANDdecreasing_only_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasing_only_reactions_gene_names
# Out:
# ['Pck',
#  'SstT',
#  'ZupT',
#  'ZupT',
#  'CorA',
#  'Adk',
#  'Ndk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Aas',
#  'MpaA',
#  'Mdh',
#  'Mqo',
#  'Adk',
#  'Ndk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'ActP',
#  'Lpd',
#  'GlcA',
#  'LldP',
#  'GcvP',
#  'GcvT',
#  'GcvH',
#  'GhrA',
#  'Adk',
#  'Ndk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'PabA',
#  'PabB',
#  'EntD',
#  'SpeE',
#  'GltA',
#  'CodA',
#  'CodB',
#  'PuuA',
#  'GlgA',
#  'ScpC',
#  'PurC',
#  'MenH',
#  'MenD',
#  'Aas',
#  'Tdk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'GuaB',
#  'AllA',
#  'GlmS',
#  'Aas',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MaeB',
#  'AtpC',
#  'AtpD',
#  'AtpB',
#  'AtpF',
#  'AtpE',
#  'AtpG',
#  'AtpA',
#  'AtpI',
#  'AtpH',
#  'Gnd',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'CdsA',
#  'NadK',
#  'PurA',
#  'LpxB',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'Adk',
#  'Aas',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'Aas',
#  'YccX',
#  'CitE',
#  'CitF',
#  'CitD',
#  'CitX',
#  'PrpB',
#  'ZitB',
#  'FieF',
#  'AcpP',
#  'PlsX',
#  'Cmk',
#  'PuuA',
#  'GlnA',
#  'GuaC',
#  'MsbA',
#  'Cdh',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Deleted',
#  'GadB',
#  'S0001',
#  'AqpZ',
#  'ZitB',
#  'FieF',
#  'ThiD',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RihC',
#  'NupC',
#  'NupG',
#  'Cdd',
#  'RihA',
#  'RihB',
#  'Udk',
#  'MsbA',
#  'Cdh',
#  'ArgB',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'FumB',
#  'FumC',
#  'FumA',
#  'DcuC',
#  'PotE',
#  'PuuP',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'Cmk',
#  'AsnA',
#  'Aas',
#  'IdnD',
#  'S0001',
#  'FsaA',
#  'FsaB',
#  'TrkA',
#  'Kch',
#  'SapD',
#  'TrkH',
#  'Kup',
#  'TrkG',
#  'FumB',
#  'DmlA',
#  'TtdA',
#  'TtdB',
#  'YccX',
#  'Pgk',
#  'Aas',
#  'ZupT',
#  'DctA',
#  'Cdh',
#  'Cmk',
#  'PyrH',
#  'Sad',
#  'GabD',
#  'GapA',
#  'NadE',
#  'Aas',
#  'AcpP',
#  'PlsX',
#  'YdjI',
#  'FbaB',
#  'FbaA',
#  'Cdh',
#  'SpoT',
#  'RelA',
#  'Deleted',
#  'DeoD',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'Lpd',
#  'SucB',
#  'SucA',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'DeoD',
#  'EamA',
#  'EamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SpoT',
#  'AspC',
#  'Aas',
#  'ZupT',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'Cdh',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AcpP',
#  'FabD',
#  'MsbA',
#  'IspH',
#  'PpsA',
#  'Prs',
#  'LeuA',
#  'DdlA',
#  'DdlB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Tmk',
#  'ThiL',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'IdnK',
#  'GntK',
#  'Aas',
#  'GuaA',
#  'RihC',
#  'RihA',
#  'RihB',
#  'ZitB',
#  'FieF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YbiV',
#  'FabB',
#  'ArgE',
#  'Adk',
#  'Ndk',
#  'GuaD',
#  'Cdh',
#  'DctA',
#  'Cdh',
#  'NadD',
#  'NadR',
#  'Adk',
#  'Ndk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'CycA',
#  'GdhA',
#  'Kbl',
#  'Udk',
#  'S0001',
#  'AmtB',
#  'MsbA',
#  'YccX',
#  'Adk',
#  'Ndk',
#  'ArgC',
#  'TalB',
#  'TalA',
#  'Deleted',
#  'DeoD',
#  'PurN',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'YccX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AdhE',
#  'MhpF',
#  'S0001',
#  'ZitB',
#  'FieF',
#  'Dcd',
#  'DeoD',
#  'Gpt',
#  'CorA',
#  'AraE',
#  'YdeA',
#  'FocB',
#  'FocA',
#  'MsbA',
#  'Tmk',
#  'Aas',
#  'FrlA',
#  'LysP',
#  'CdsA',
#  'ZupT',
#  'Aas',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'GldA',
#  'YccX',
#  'MgsA',
#  'PitA',
#  'PitB',
#  'CynT',
#  'Can',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'AcnA',
#  'AcnB',
#  'Aas',
#  'FolK',
#  'Ppk',
#  'Gmk',
#  'PurB',
#  'TpiA',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'PurU',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'NadD',
#  'Gmk',
#  'S0001',
#  'Dld',
#  'LdhA',
#  'PntA',
#  'PntB',
#  'ArgA',
#  'YccX',
#  'MsbA',
#  'AccA',
#  'AccC',
#  'AccD',
#  'AccB',
#  'GpsA',
#  'Aas',
#  'AceB',
#  'GlcB',
#  'GlpK',
#  'Deleted',
#  'Rpe',
#  'AcnA',
#  'AcnB',
#  'YccX',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'PflD',
#  'PflC',
#  'Alr',
#  'DadX',
#  'Udp',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'OmpL',
#  'OmpG',
#  'OmpA',
#  'GlpX',
#  'YggF',
#  'Fbp',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'MsbA',
#  'Ppc',
#  'Dfp',
#  'Pck',
#  'ScpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Pgl',
#  'Gph',
#  'GhrB',
#  'GhrA',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE']

# %%
Ushaped_gene_names = list( dict.fromkeys(Ushaped_gene_names) ) #remove duplicates in the list. I think that you convert it to dictionary and back to list (not sure)
one_gene_names = list( dict.fromkeys(one_gene_names) )
flat_gene_names = list( dict.fromkeys(flat_gene_names) )
saturated_gene_names = list( dict.fromkeys(saturated_gene_names) )
monotonically_increasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_increasingANDstable_reactions_gene_names) )
monotonically_increasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_increasing_only_reactions_gene_names) )
monotonically_decreasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_decreasingANDstable_reactions_gene_names) )
monotonically_decreasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_decreasing_only_reactions_gene_names) )
increasingANDdecreasingANDstable_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasingANDstable_reactions_gene_names) )
increasingANDdecreasing_only_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasing_only_reactions_gene_names) )

d1= pd.DataFrame(Ushaped_gene_names, columns= ["Gene names for Ushaped reactions"])
d2= pd.DataFrame(one_gene_names, columns= ["Gene names for reactions with one feasible value"])
d3= pd.DataFrame(flat_gene_names, columns= ["Gene names for flat reactions"])
d4= pd.DataFrame(saturated_gene_names, columns= ["Gene names for saturating reactions"])
d5= pd.DataFrame(monotonically_increasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and stable reactions"])
d6= pd.DataFrame(monotonically_increasing_only_reactions_gene_names, columns= ["Gene names for increasing only reactions"])
d7= pd.DataFrame(monotonically_decreasingANDstable_reactions_gene_names, columns= ["Gene names for decreasing and stable reactions"])
d8= pd.DataFrame(monotonically_decreasing_only_reactions_gene_names, columns= ["Gene names for decreasing only reactions"])
d9= pd.DataFrame(increasingANDdecreasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and decreasing and stable reactions"])
d10= pd.DataFrame(increasingANDdecreasing_only_reactions_gene_names, columns= ["Gene names for increasing and decreasing only reactions"])

csv_Ushaped_gene_names = d1.to_csv('Ushaped_gene_names M9 media.csv', index = True)
csv_one_gene_names = d2.to_csv('one_gene_names M9 media.csv', index = True) 
csv_flat_gene_names = d3.to_csv('flat_gene_names M9 media.csv', index = True)
csv_saturated_gene_names = d4.to_csv('saturated_gene_names M9 media.csv', index = True)
csv_monotonically_increasingANDstable_reactions_gene_names = d5.to_csv('monotonically_increasingANDstable_reactions_gene_names M9 media.csv', index = True)
csv_monotonically_increasing_only_reactions_gene_names = d6.to_csv('monotonically_increasing_only_reactions_gene_names M9 media.csv', index = True)
csv_monotonically_decreasingANDstable_reactions_gene_names = d7.to_csv('monotonically_decreasingANDstable_reactions_gene_names M9 media.csv', index = True)
csv_monotonically_decreasing_only_reactions_gene_names = d8.to_csv('monotonically_decreasing_only_reactions_gene_names M9 media.csv', index = True)
csv_increasingANDdecreasingANDstable_reactions_gene_names = d9.to_csv('increasingANDdecreasingANDstable_reactions_gene_names M9 media.csv', index = True)
csv_increasingANDdecreasing_only_reactions_gene_names = d10.to_csv('increasingANDdecreasing_only_reactions_gene_names M9 media.csv', index = True)
